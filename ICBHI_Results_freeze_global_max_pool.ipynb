# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.figure
from pathlib import Path
import os
import wave
import keras
import seaborn as sns
import librosa
import soundfile as sf
from google.colab import drive
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from numpy import mean
from numpy import std
import tensorflow as tf
from numpy import dstack
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.utils import to_categorical
from scipy.io import wavfile
from tqdm import tqdm
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.applications import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping
# !pip install mat73
import mat73
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mat73
#   Downloading mat73-0.59-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mat73) (1.21.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from mat73) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->mat73) (1.5.2)
# Installing collected packages: mat73
# Successfully installed mat73-0.59

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import scipy
sig_dict = scipy.io.loadmat('/content/gdrive/MyDrive/ICBHI_Results/train_img.mat')
X=sig_dict['train_img']

# %%
labels=pd.read_excel('/content/gdrive/MyDrive/ICBHI_Results/Labels.xlsx',header=None)
labels.columns=["Lung Sound"]
class_label_onehot=pd.get_dummies(labels)
Y=np.array(class_label_onehot);
print(X.shape)
print(Y.shape)
# Out:
# (9217, 64, 64, 3)
# (9217, 6)

# %%
custom_early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=100, 
    min_delta=0.001, 
    mode='max'
)

# %%
def mobile_inception(dim, output_neurons, output_activation):
    print("\nTRAINING ON mobile_inception MODEL:-")

    
    def block(x, filters, reps):
        for _ in range(reps):
            # for low-level features
            t1 = Conv2D(filters[0], kernel_size = (1,1))(x)
            t1 = LeakyReLU()(t1)

            # for mid-level features
            t2 = DepthwiseConv2D(kernel_size = (3,3), strides = 1, padding = 'same')(x)
            t2 = LeakyReLU()(t2)
            t2 = Conv2D(filters[1], kernel_size = (1,1))(t2)
            t2 = LeakyReLU()(t2)

            # for high-level features
            t3 = DepthwiseConv2D(kernel_size = (5,5), strides = 1, padding = 'same')(x)
            t3 = LeakyReLU()(t3)
            t3 = Conv2D(filters[2], kernel_size = (1,1))(t3)
            t3 = LeakyReLU()(t3)

            # for most-significant features
            t4 = MaxPool2D(pool_size = (3,3), strides = 1, padding = 'same')(x)
            t4 = Conv2D(filters[3], kernel_size = (1,1))(t4)
            t4 = LeakyReLU()(t4)

            x = Concatenate()([t1, t2, t3, t4])
        
        return x
        
        
    input = Input(shape = dim)
    
    k = 16
    
    x = Conv2D(filters = k, kernel_size = (3,3), strides = 2, padding = 'same')(input)
    x = LeakyReLU()(x)
    x = MaxPool2D(pool_size = (3,3), strides = 2, padding = 'same')(x)
    
    x = DepthwiseConv2D(kernel_size = (3,3), strides = 1, padding = 'same')(x)
    x = LeakyReLU()(x)
    x = Conv2D(filters = 2*k, kernel_size = (1,1))(x)
    x = LeakyReLU()(x)
    x = MaxPool2D(pool_size = (2,2), strides = 2)(x)
    
    x = block(x, [k, k, k, k], reps = 2)
    x = MaxPool2D(pool_size = (2,2), strides = 2)(x)
        
    x = GlobalMaxPooling2D()(x)
    x = Dropout(0.3)(x)
    x=  Dense(40, 'relu')(x)
    x = Dropout(0.2)(x)
    output = Dense(output_neurons, output_activation)(x)
    
    model = Model(inputs = input, outputs = output)    
    
    return model

# %%
dim = (64,64,3)
output_neurons = 6
output_activation = 'softmax'
from keras import backend as Ke
Ke.clear_session()
model = mobile_inception(dim, output_neurons, output_activation)
#model.summary()
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# TRAINING ON mobile_inception MODEL:-

# %%
from datetime import date
today = date.today()
f_date=today.strftime("%d_%m_%y")
os.mkdir("/content/gdrive/My Drive/ICBHI_Results/train_on_"+(f_date))
new_loc="/content/gdrive/My Drive/ICBHI_Results/train_on_"+(f_date)

# %%
    import random
    import seaborn as sns
    from sklearn.metrics import classification_report
    p=10;
    print('Random_seed_value== '+str(p))
    X_train_1,X_test,Y_train_1,Y_test=train_test_split(X,Y,test_size=0.1,random_state=p)
    X_train,X_val,Y_train,Y_val=train_test_split(X_train_1,Y_train_1,test_size=0.1,random_state=p)
# Out:
# Random_seed_value== 10

# %%
    print("================================================================================================")  
    from keras import backend as Ke
    #Ke.clear_session()
    model = mobile_inception(dim, output_neurons, output_activation)
    opt =tf.keras.optimizers.Adam(learning_rate=0.008) 
    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])

    history = model.fit(X_train, Y_train, batch_size=128, epochs=500, verbose=1,validation_data=(X_val, Y_val))#,callbacks=[custom_early_stopping])
# Out:
# ================================================================================================
#
# TRAINING ON mobile_inception MODEL:-
# Epoch 1/500
# 30/30 [==============================] - 19s 587ms/step - loss: 1.4741 - accuracy: 0.5211 - val_loss: 1.3586 - val_accuracy: 0.5578
# Epoch 2/500
# 30/30 [==============================] - 17s 556ms/step - loss: 1.3573 - accuracy: 0.5499 - val_loss: 1.2340 - val_accuracy: 0.5747
# Epoch 3/500
# 30/30 [==============================] - 16s 519ms/step - loss: 1.2065 - accuracy: 0.5676 - val_loss: 1.0548 - val_accuracy: 0.5928
# Epoch 4/500
# 30/30 [==============================] - 16s 548ms/step - loss: 1.0456 - accuracy: 0.5995 - val_loss: 0.9392 - val_accuracy: 0.6386
# Epoch 5/500
# 30/30 [==============================] - 15s 505ms/step - loss: 0.9449 - accuracy: 0.6272 - val_loss: 0.9886 - val_accuracy: 0.6373
# Epoch 6/500
# 30/30 [==============================] - 15s 506ms/step - loss: 0.9171 - accuracy: 0.6374 - val_loss: 0.8179 - val_accuracy: 0.7024
# Epoch 7/500
# 30/30 [==============================] - 17s 574ms/step - loss: 0.8174 - accuracy: 0.6758 - val_loss: 0.7400 - val_accuracy: 0.7542
# Epoch 8/500
# 30/30 [==============================] - 18s 611ms/step - loss: 0.7480 - accuracy: 0.7065 - val_loss: 0.6806 - val_accuracy: 0.7494
# Epoch 9/500
# 30/30 [==============================] - 18s 590ms/step - loss: 0.6968 - accuracy: 0.7248 - val_loss: 0.6156 - val_accuracy: 0.7663
# Epoch 10/500
# 30/30 [==============================] - 17s 570ms/step - loss: 0.6266 - accuracy: 0.7541 - val_loss: 0.5511 - val_accuracy: 0.7964
# Epoch 11/500
# 30/30 [==============================] - 19s 641ms/step - loss: 0.6237 - accuracy: 0.7586 - val_loss: 0.5846 - val_accuracy: 0.7831
# Epoch 12/500
# 30/30 [==============================] - 17s 566ms/step - loss: 0.5986 - accuracy: 0.7664 - val_loss: 0.5398 - val_accuracy: 0.8024
# Epoch 13/500
# 30/30 [==============================] - 17s 588ms/step - loss: 0.5253 - accuracy: 0.7956 - val_loss: 0.5309 - val_accuracy: 0.7928
# Epoch 14/500
# 30/30 [==============================] - 17s 584ms/step - loss: 0.5070 - accuracy: 0.8047 - val_loss: 0.4881 - val_accuracy: 0.8205
# Epoch 15/500
# 30/30 [==============================] - 16s 535ms/step - loss: 0.4628 - accuracy: 0.8141 - val_loss: 0.5309 - val_accuracy: 0.8036
# Epoch 16/500
# 30/30 [==============================] - 15s 513ms/step - loss: 0.4505 - accuracy: 0.8230 - val_loss: 0.3985 - val_accuracy: 0.8470
# Epoch 17/500
# 30/30 [==============================] - 17s 575ms/step - loss: 0.4341 - accuracy: 0.8285 - val_loss: 0.4225 - val_accuracy: 0.8482
# Epoch 18/500
# 30/30 [==============================] - 14s 458ms/step - loss: 0.4292 - accuracy: 0.8303 - val_loss: 0.4246 - val_accuracy: 0.8446
# Epoch 19/500
# 30/30 [==============================] - 14s 484ms/step - loss: 0.4006 - accuracy: 0.8462 - val_loss: 0.3574 - val_accuracy: 0.8675
# Epoch 20/500
# 30/30 [==============================] - 16s 529ms/step - loss: 0.4432 - accuracy: 0.8251 - val_loss: 0.4209 - val_accuracy: 0.8470
# Epoch 21/500
# 30/30 [==============================] - 19s 650ms/step - loss: 0.3679 - accuracy: 0.8576 - val_loss: 0.3472 - val_accuracy: 0.8699
# Epoch 22/500
# 30/30 [==============================] - 14s 482ms/step - loss: 0.3742 - accuracy: 0.8532 - val_loss: 0.3526 - val_accuracy: 0.8651
# Epoch 23/500
# 30/30 [==============================] - 15s 507ms/step - loss: 0.3408 - accuracy: 0.8689 - val_loss: 0.3616 - val_accuracy: 0.8639
# Epoch 24/500
# 30/30 [==============================] - 17s 566ms/step - loss: 0.3554 - accuracy: 0.8603 - val_loss: 0.3158 - val_accuracy: 0.8831
# Epoch 25/500
# 30/30 [==============================] - 19s 631ms/step - loss: 0.3738 - accuracy: 0.8551 - val_loss: 0.3075 - val_accuracy: 0.8880
# Epoch 26/500
# 30/30 [==============================] - 17s 580ms/step - loss: 0.3337 - accuracy: 0.8709 - val_loss: 0.2908 - val_accuracy: 0.8916
# Epoch 27/500
# 30/30 [==============================] - 17s 581ms/step - loss: 0.3293 - accuracy: 0.8729 - val_loss: 0.3048 - val_accuracy: 0.8843
# Epoch 28/500
# 30/30 [==============================] - 16s 551ms/step - loss: 0.2949 - accuracy: 0.8856 - val_loss: 0.2674 - val_accuracy: 0.9036
# Epoch 29/500
# 30/30 [==============================] - 15s 497ms/step - loss: 0.2746 - accuracy: 0.8915 - val_loss: 0.2708 - val_accuracy: 0.9036
# Epoch 30/500
# 30/30 [==============================] - 17s 567ms/step - loss: 0.2883 - accuracy: 0.8881 - val_loss: 0.2854 - val_accuracy: 0.8964
# Epoch 31/500
# 30/30 [==============================] - 15s 494ms/step - loss: 0.3260 - accuracy: 0.8698 - val_loss: 0.2774 - val_accuracy: 0.8855
# Epoch 32/500
# 30/30 [==============================] - 17s 569ms/step - loss: 0.2926 - accuracy: 0.8896 - val_loss: 0.2559 - val_accuracy: 0.9036
# Epoch 33/500
# 30/30 [==============================] - 16s 532ms/step - loss: 0.2686 - accuracy: 0.8952 - val_loss: 0.2495 - val_accuracy: 0.9108
# Epoch 34/500
# 30/30 [==============================] - 16s 532ms/step - loss: 0.2616 - accuracy: 0.8959 - val_loss: 0.2238 - val_accuracy: 0.9265
# Epoch 35/500
# 30/30 [==============================] - 16s 537ms/step - loss: 0.2431 - accuracy: 0.9033 - val_loss: 0.2366 - val_accuracy: 0.9229
# Epoch 36/500
# 30/30 [==============================] - 16s 551ms/step - loss: 0.2640 - accuracy: 0.8987 - val_loss: 0.3095 - val_accuracy: 0.8928
# Epoch 37/500
# 30/30 [==============================] - 14s 455ms/step - loss: 0.2541 - accuracy: 0.9018 - val_loss: 0.2107 - val_accuracy: 0.9301
# Epoch 38/500
# 30/30 [==============================] - 15s 519ms/step - loss: 0.2364 - accuracy: 0.9056 - val_loss: 0.2547 - val_accuracy: 0.9096
# Epoch 39/500
# 30/30 [==============================] - 15s 512ms/step - loss: 0.2271 - accuracy: 0.9117 - val_loss: 0.2365 - val_accuracy: 0.9241
# Epoch 40/500
# 30/30 [==============================] - 14s 483ms/step - loss: 0.2182 - accuracy: 0.9187 - val_loss: 0.2250 - val_accuracy: 0.9241
# Epoch 41/500
# 30/30 [==============================] - 17s 557ms/step - loss: 0.2247 - accuracy: 0.9093 - val_loss: 0.2282 - val_accuracy: 0.9229
# Epoch 42/500
# 30/30 [==============================] - 15s 488ms/step - loss: 0.2305 - accuracy: 0.9116 - val_loss: 0.1951 - val_accuracy: 0.9337
# Epoch 43/500
# 30/30 [==============================] - 15s 489ms/step - loss: 0.2240 - accuracy: 0.9117 - val_loss: 0.2094 - val_accuracy: 0.9253
# Epoch 44/500
# 30/30 [==============================] - 21s 711ms/step - loss: 0.2328 - accuracy: 0.9131 - val_loss: 0.2177 - val_accuracy: 0.9229
# Epoch 45/500
# 30/30 [==============================] - 17s 582ms/step - loss: 0.2069 - accuracy: 0.9218 - val_loss: 0.2261 - val_accuracy: 0.9181
# Epoch 46/500
# 30/30 [==============================] - 17s 564ms/step - loss: 0.2144 - accuracy: 0.9171 - val_loss: 0.2399 - val_accuracy: 0.9217
# Epoch 47/500
# 30/30 [==============================] - 20s 672ms/step - loss: 0.2156 - accuracy: 0.9161 - val_loss: 0.2177 - val_accuracy: 0.9241
# Epoch 48/500
# 30/30 [==============================] - 15s 508ms/step - loss: 0.1934 - accuracy: 0.9259 - val_loss: 0.2155 - val_accuracy: 0.9289
# Epoch 49/500
# 30/30 [==============================] - 15s 495ms/step - loss: 0.1754 - accuracy: 0.9310 - val_loss: 0.2486 - val_accuracy: 0.9217
# Epoch 50/500
# 30/30 [==============================] - 16s 551ms/step - loss: 0.2203 - accuracy: 0.9112 - val_loss: 0.2039 - val_accuracy: 0.9301
# Epoch 51/500
# 30/30 [==============================] - 14s 485ms/step - loss: 0.1948 - accuracy: 0.9199 - val_loss: 0.2343 - val_accuracy: 0.9241
# Epoch 52/500
# 30/30 [==============================] - 16s 535ms/step - loss: 0.1901 - accuracy: 0.9253 - val_loss: 0.2153 - val_accuracy: 0.9301
# Epoch 53/500
# 30/30 [==============================] - 15s 511ms/step - loss: 0.1860 - accuracy: 0.9307 - val_loss: 0.1952 - val_accuracy: 0.9337
# Epoch 54/500
# 30/30 [==============================] - 14s 486ms/step - loss: 0.1892 - accuracy: 0.9279 - val_loss: 0.2520 - val_accuracy: 0.9096
# Epoch 55/500
# 30/30 [==============================] - 16s 542ms/step - loss: 0.1830 - accuracy: 0.9297 - val_loss: 0.1916 - val_accuracy: 0.9349
# Epoch 56/500
# 30/30 [==============================] - 17s 578ms/step - loss: 0.1818 - accuracy: 0.9278 - val_loss: 0.2442 - val_accuracy: 0.9205
# Epoch 57/500
# 30/30 [==============================] - 18s 605ms/step - loss: 0.2084 - accuracy: 0.9204 - val_loss: 0.2051 - val_accuracy: 0.9313
# Epoch 58/500
# 30/30 [==============================] - 16s 536ms/step - loss: 0.1763 - accuracy: 0.9303 - val_loss: 0.1957 - val_accuracy: 0.9325
# Epoch 59/500
# 30/30 [==============================] - 19s 624ms/step - loss: 0.1736 - accuracy: 0.9346 - val_loss: 0.2178 - val_accuracy: 0.9301
# Epoch 60/500
# 30/30 [==============================] - 17s 585ms/step - loss: 0.1778 - accuracy: 0.9302 - val_loss: 0.1999 - val_accuracy: 0.9373
# Epoch 61/500
# 30/30 [==============================] - 15s 504ms/step - loss: 0.1604 - accuracy: 0.9376 - val_loss: 0.2187 - val_accuracy: 0.9349
# Epoch 62/500
# 30/30 [==============================] - 17s 565ms/step - loss: 0.1681 - accuracy: 0.9352 - val_loss: 0.2084 - val_accuracy: 0.9349
# Epoch 63/500
# 30/30 [==============================] - 15s 517ms/step - loss: 0.1726 - accuracy: 0.9330 - val_loss: 0.1973 - val_accuracy: 0.9386
# Epoch 64/500
# 30/30 [==============================] - 17s 562ms/step - loss: 0.1743 - accuracy: 0.9357 - val_loss: 0.2271 - val_accuracy: 0.9289
# Epoch 65/500
# 30/30 [==============================] - 17s 564ms/step - loss: 0.1774 - accuracy: 0.9324 - val_loss: 0.1900 - val_accuracy: 0.9373
# Epoch 66/500
# 30/30 [==============================] - 15s 498ms/step - loss: 0.1634 - accuracy: 0.9362 - val_loss: 0.2080 - val_accuracy: 0.9337
# Epoch 67/500
# 30/30 [==============================] - 17s 557ms/step - loss: 0.1586 - accuracy: 0.9365 - val_loss: 0.2314 - val_accuracy: 0.9325
# Epoch 68/500
# 30/30 [==============================] - 17s 581ms/step - loss: 0.1598 - accuracy: 0.9361 - val_loss: 0.2290 - val_accuracy: 0.9313
# Epoch 69/500
# 30/30 [==============================] - 17s 564ms/step - loss: 0.1831 - accuracy: 0.9275 - val_loss: 0.3640 - val_accuracy: 0.8807
# Epoch 70/500
# 30/30 [==============================] - 16s 553ms/step - loss: 0.2059 - accuracy: 0.9195 - val_loss: 0.2059 - val_accuracy: 0.9349
# Epoch 71/500
# 30/30 [==============================] - 17s 581ms/step - loss: 0.1753 - accuracy: 0.9309 - val_loss: 0.1778 - val_accuracy: 0.9422
# Epoch 72/500
# 30/30 [==============================] - 16s 529ms/step - loss: 0.1565 - accuracy: 0.9393 - val_loss: 0.2076 - val_accuracy: 0.9349
# Epoch 73/500
# 30/30 [==============================] - 18s 614ms/step - loss: 0.1669 - accuracy: 0.9341 - val_loss: 0.2032 - val_accuracy: 0.9398
# Epoch 74/500
# 30/30 [==============================] - 16s 531ms/step - loss: 0.1558 - accuracy: 0.9381 - val_loss: 0.2090 - val_accuracy: 0.9325
# Epoch 75/500
# 30/30 [==============================] - 17s 579ms/step - loss: 0.1387 - accuracy: 0.9444 - val_loss: 0.1942 - val_accuracy: 0.9386
# Epoch 76/500
# 30/30 [==============================] - 15s 485ms/step - loss: 0.1398 - accuracy: 0.9453 - val_loss: 0.2024 - val_accuracy: 0.9325
# Epoch 77/500
# 30/30 [==============================] - 16s 534ms/step - loss: 0.1518 - accuracy: 0.9428 - val_loss: 0.2035 - val_accuracy: 0.9325
# Epoch 78/500
# 30/30 [==============================] - 19s 627ms/step - loss: 0.1511 - accuracy: 0.9416 - val_loss: 0.1978 - val_accuracy: 0.9337
# Epoch 79/500
# 30/30 [==============================] - 18s 615ms/step - loss: 0.1421 - accuracy: 0.9425 - val_loss: 0.1815 - val_accuracy: 0.9386
# Epoch 80/500
# 30/30 [==============================] - 15s 505ms/step - loss: 0.1544 - accuracy: 0.9399 - val_loss: 0.1843 - val_accuracy: 0.9386
# Epoch 81/500
# 30/30 [==============================] - 18s 586ms/step - loss: 0.1616 - accuracy: 0.9333 - val_loss: 0.2204 - val_accuracy: 0.9265
# Epoch 82/500
# 30/30 [==============================] - 16s 551ms/step - loss: 0.1868 - accuracy: 0.9261 - val_loss: 0.2383 - val_accuracy: 0.9289
# Epoch 83/500
# 30/30 [==============================] - 15s 517ms/step - loss: 0.1488 - accuracy: 0.9401 - val_loss: 0.1975 - val_accuracy: 0.9398
# Epoch 84/500
# 30/30 [==============================] - 16s 548ms/step - loss: 0.1788 - accuracy: 0.9302 - val_loss: 0.1906 - val_accuracy: 0.9446
# Epoch 85/500
# 30/30 [==============================] - 17s 557ms/step - loss: 0.1375 - accuracy: 0.9466 - val_loss: 0.1980 - val_accuracy: 0.9410
# Epoch 86/500
# 30/30 [==============================] - 16s 537ms/step - loss: 0.1373 - accuracy: 0.9464 - val_loss: 0.1839 - val_accuracy: 0.9398
# Epoch 87/500
# 30/30 [==============================] - 20s 691ms/step - loss: 0.1372 - accuracy: 0.9468 - val_loss: 0.1896 - val_accuracy: 0.9446
# Epoch 88/500
# 30/30 [==============================] - 16s 534ms/step - loss: 0.1510 - accuracy: 0.9421 - val_loss: 0.1910 - val_accuracy: 0.9325
# Epoch 89/500
# 30/30 [==============================] - 17s 580ms/step - loss: 0.1422 - accuracy: 0.9452 - val_loss: 0.2429 - val_accuracy: 0.9337
# Epoch 90/500
# 30/30 [==============================] - 14s 485ms/step - loss: 0.1342 - accuracy: 0.9480 - val_loss: 0.2551 - val_accuracy: 0.9145
# Epoch 91/500
# 30/30 [==============================] - 18s 597ms/step - loss: 0.1950 - accuracy: 0.9259 - val_loss: 0.2016 - val_accuracy: 0.9398
# Epoch 92/500
# 30/30 [==============================] - 14s 481ms/step - loss: 0.1572 - accuracy: 0.9409 - val_loss: 0.2406 - val_accuracy: 0.9313
# Epoch 93/500
# 30/30 [==============================] - 16s 543ms/step - loss: 0.1426 - accuracy: 0.9459 - val_loss: 0.1958 - val_accuracy: 0.9422
# Epoch 94/500
# 30/30 [==============================] - 16s 536ms/step - loss: 0.1234 - accuracy: 0.9506 - val_loss: 0.2030 - val_accuracy: 0.9361
# Epoch 95/500
# 30/30 [==============================] - 15s 514ms/step - loss: 0.1846 - accuracy: 0.9311 - val_loss: 0.1816 - val_accuracy: 0.9361
# Epoch 96/500
# 30/30 [==============================] - 16s 523ms/step - loss: 0.1385 - accuracy: 0.9472 - val_loss: 0.2518 - val_accuracy: 0.9241
# Epoch 97/500
# 30/30 [==============================] - 15s 489ms/step - loss: 0.1438 - accuracy: 0.9451 - val_loss: 0.2157 - val_accuracy: 0.9361
# Epoch 98/500
# 30/30 [==============================] - 18s 602ms/step - loss: 0.1546 - accuracy: 0.9395 - val_loss: 0.1688 - val_accuracy: 0.9458
# Epoch 99/500
# 30/30 [==============================] - 21s 713ms/step - loss: 0.1261 - accuracy: 0.9503 - val_loss: 0.1730 - val_accuracy: 0.9422
# Epoch 100/500
# 30/30 [==============================] - 15s 517ms/step - loss: 0.1154 - accuracy: 0.9559 - val_loss: 0.1777 - val_accuracy: 0.9422
# Epoch 101/500
# 30/30 [==============================] - 14s 482ms/step - loss: 0.1107 - accuracy: 0.9563 - val_loss: 0.1848 - val_accuracy: 0.9434
# Epoch 102/500
# 30/30 [==============================] - 18s 593ms/step - loss: 0.1047 - accuracy: 0.9595 - val_loss: 0.1808 - val_accuracy: 0.9470
# Epoch 103/500
# 30/30 [==============================] - 17s 576ms/step - loss: 0.1092 - accuracy: 0.9546 - val_loss: 0.1881 - val_accuracy: 0.9398
# Epoch 104/500
# 30/30 [==============================] - 15s 506ms/step - loss: 0.1177 - accuracy: 0.9545 - val_loss: 0.2194 - val_accuracy: 0.9386
# Epoch 105/500
# 30/30 [==============================] - 19s 647ms/step - loss: 0.1432 - accuracy: 0.9464 - val_loss: 0.2004 - val_accuracy: 0.9434
# Epoch 106/500
# 30/30 [==============================] - 14s 475ms/step - loss: 0.1429 - accuracy: 0.9464 - val_loss: 0.2009 - val_accuracy: 0.9398
# Epoch 107/500
# 30/30 [==============================] - 18s 608ms/step - loss: 0.1125 - accuracy: 0.9565 - val_loss: 0.1977 - val_accuracy: 0.9434
# Epoch 108/500
# 30/30 [==============================] - 16s 550ms/step - loss: 0.1046 - accuracy: 0.9574 - val_loss: 0.2032 - val_accuracy: 0.9434
# Epoch 109/500
# 30/30 [==============================] - 16s 525ms/step - loss: 0.1082 - accuracy: 0.9573 - val_loss: 0.1965 - val_accuracy: 0.9458
# Epoch 110/500
# 30/30 [==============================] - 15s 509ms/step - loss: 0.1182 - accuracy: 0.9539 - val_loss: 0.2288 - val_accuracy: 0.9289
# Epoch 111/500
# 30/30 [==============================] - 17s 561ms/step - loss: 0.1220 - accuracy: 0.9506 - val_loss: 0.2632 - val_accuracy: 0.9265
# Epoch 112/500
# 30/30 [==============================] - 17s 565ms/step - loss: 0.1024 - accuracy: 0.9587 - val_loss: 0.2155 - val_accuracy: 0.9458
# Epoch 113/500
# 30/30 [==============================] - 15s 507ms/step - loss: 0.1038 - accuracy: 0.9582 - val_loss: 0.1781 - val_accuracy: 0.9506
# Epoch 114/500
# 30/30 [==============================] - 17s 569ms/step - loss: 0.1164 - accuracy: 0.9562 - val_loss: 0.2888 - val_accuracy: 0.9325
# Epoch 115/500
# 30/30 [==============================] - 16s 555ms/step - loss: 0.1298 - accuracy: 0.9476 - val_loss: 0.2073 - val_accuracy: 0.9386
# Epoch 116/500
# 30/30 [==============================] - 16s 554ms/step - loss: 0.1203 - accuracy: 0.9547 - val_loss: 0.2192 - val_accuracy: 0.9410
# Epoch 117/500
# 30/30 [==============================] - 15s 511ms/step - loss: 0.1215 - accuracy: 0.9527 - val_loss: 0.2110 - val_accuracy: 0.9422
# Epoch 118/500
# 30/30 [==============================] - 18s 611ms/step - loss: 0.1126 - accuracy: 0.9549 - val_loss: 0.2410 - val_accuracy: 0.9386
# Epoch 119/500
# 30/30 [==============================] - 14s 470ms/step - loss: 0.1209 - accuracy: 0.9530 - val_loss: 0.2214 - val_accuracy: 0.9386
# Epoch 120/500
# 30/30 [==============================] - 15s 515ms/step - loss: 0.1088 - accuracy: 0.9595 - val_loss: 0.2762 - val_accuracy: 0.9325
# Epoch 121/500
# 30/30 [==============================] - 15s 513ms/step - loss: 0.1334 - accuracy: 0.9503 - val_loss: 0.2243 - val_accuracy: 0.9410
# Epoch 122/500
# 30/30 [==============================] - 16s 526ms/step - loss: 0.1493 - accuracy: 0.9452 - val_loss: 0.2000 - val_accuracy: 0.9434
# Epoch 123/500
# 30/30 [==============================] - 15s 504ms/step - loss: 0.1521 - accuracy: 0.9401 - val_loss: 0.3700 - val_accuracy: 0.9108
# Epoch 124/500
# 30/30 [==============================] - 17s 556ms/step - loss: 0.1576 - accuracy: 0.9433 - val_loss: 0.2115 - val_accuracy: 0.9446
# Epoch 125/500
# 30/30 [==============================] - 18s 607ms/step - loss: 0.1307 - accuracy: 0.9506 - val_loss: 0.2066 - val_accuracy: 0.9434
# Epoch 126/500
# 30/30 [==============================] - 16s 533ms/step - loss: 0.1218 - accuracy: 0.9523 - val_loss: 0.2345 - val_accuracy: 0.9313
# Epoch 127/500
# 30/30 [==============================] - 16s 551ms/step - loss: 0.1294 - accuracy: 0.9487 - val_loss: 0.2393 - val_accuracy: 0.9337
# Epoch 128/500
# 30/30 [==============================] - 15s 513ms/step - loss: 0.1118 - accuracy: 0.9557 - val_loss: 0.2193 - val_accuracy: 0.9422
# Epoch 129/500
# 30/30 [==============================] - 17s 571ms/step - loss: 0.1118 - accuracy: 0.9565 - val_loss: 0.1876 - val_accuracy: 0.9506
# Epoch 130/500
# 30/30 [==============================] - 16s 549ms/step - loss: 0.1079 - accuracy: 0.9579 - val_loss: 0.1968 - val_accuracy: 0.9470
# Epoch 131/500
# 30/30 [==============================] - 17s 589ms/step - loss: 0.1111 - accuracy: 0.9573 - val_loss: 0.2256 - val_accuracy: 0.9422
# Epoch 132/500
# 30/30 [==============================] - 17s 554ms/step - loss: 0.1661 - accuracy: 0.9417 - val_loss: 0.2179 - val_accuracy: 0.9337
# Epoch 133/500
# 30/30 [==============================] - 15s 511ms/step - loss: 0.1295 - accuracy: 0.9496 - val_loss: 0.2000 - val_accuracy: 0.9530
# Epoch 134/500
# 30/30 [==============================] - 16s 552ms/step - loss: 0.1146 - accuracy: 0.9575 - val_loss: 0.1831 - val_accuracy: 0.9542
# Epoch 135/500
# 30/30 [==============================] - 18s 590ms/step - loss: 0.0978 - accuracy: 0.9625 - val_loss: 0.1891 - val_accuracy: 0.9458
# Epoch 136/500
# 30/30 [==============================] - 14s 476ms/step - loss: 0.0949 - accuracy: 0.9621 - val_loss: 0.2080 - val_accuracy: 0.9422
# Epoch 137/500
# 30/30 [==============================] - 17s 559ms/step - loss: 0.0794 - accuracy: 0.9689 - val_loss: 0.2116 - val_accuracy: 0.9446
# Epoch 138/500
# 30/30 [==============================] - 16s 530ms/step - loss: 0.1042 - accuracy: 0.9603 - val_loss: 0.2540 - val_accuracy: 0.9349
# Epoch 139/500
# 30/30 [==============================] - 17s 557ms/step - loss: 0.1087 - accuracy: 0.9602 - val_loss: 0.1875 - val_accuracy: 0.9422
# Epoch 140/500
# 30/30 [==============================] - 16s 542ms/step - loss: 0.0926 - accuracy: 0.9636 - val_loss: 0.2608 - val_accuracy: 0.9361
# Epoch 141/500
# 30/30 [==============================] - 16s 544ms/step - loss: 0.1382 - accuracy: 0.9518 - val_loss: 0.2747 - val_accuracy: 0.9361
# Epoch 142/500
# 30/30 [==============================] - 18s 612ms/step - loss: 0.0966 - accuracy: 0.9599 - val_loss: 0.2827 - val_accuracy: 0.9241
# Epoch 143/500
# 30/30 [==============================] - 15s 504ms/step - loss: 0.1019 - accuracy: 0.9595 - val_loss: 0.2051 - val_accuracy: 0.9434
# Epoch 144/500
# 30/30 [==============================] - 16s 535ms/step - loss: 0.0973 - accuracy: 0.9609 - val_loss: 0.2594 - val_accuracy: 0.9373
# Epoch 145/500
# 30/30 [==============================] - 14s 472ms/step - loss: 0.1455 - accuracy: 0.9463 - val_loss: 0.1771 - val_accuracy: 0.9518
# Epoch 146/500
# 30/30 [==============================] - 16s 532ms/step - loss: 0.1007 - accuracy: 0.9591 - val_loss: 0.2392 - val_accuracy: 0.9361
# Epoch 147/500
# 30/30 [==============================] - 18s 591ms/step - loss: 0.1004 - accuracy: 0.9624 - val_loss: 0.2051 - val_accuracy: 0.9458
# Epoch 148/500
# 30/30 [==============================] - 14s 474ms/step - loss: 0.1115 - accuracy: 0.9599 - val_loss: 0.2986 - val_accuracy: 0.9277
# Epoch 149/500
# 30/30 [==============================] - 15s 501ms/step - loss: 0.1019 - accuracy: 0.9603 - val_loss: 0.1813 - val_accuracy: 0.9518
# Epoch 150/500
# 30/30 [==============================] - 17s 583ms/step - loss: 0.0975 - accuracy: 0.9632 - val_loss: 0.1929 - val_accuracy: 0.9506
# Epoch 151/500
# 30/30 [==============================] - 15s 495ms/step - loss: 0.0844 - accuracy: 0.9673 - val_loss: 0.2272 - val_accuracy: 0.9434
# Epoch 152/500
# 30/30 [==============================] - 15s 514ms/step - loss: 0.1065 - accuracy: 0.9618 - val_loss: 0.2071 - val_accuracy: 0.9458
# Epoch 153/500
# 30/30 [==============================] - 16s 549ms/step - loss: 0.1069 - accuracy: 0.9589 - val_loss: 0.2162 - val_accuracy: 0.9361
# Epoch 154/500
# 30/30 [==============================] - 15s 502ms/step - loss: 0.1153 - accuracy: 0.9565 - val_loss: 0.1962 - val_accuracy: 0.9518
# Epoch 155/500
# 30/30 [==============================] - 18s 597ms/step - loss: 0.1002 - accuracy: 0.9629 - val_loss: 0.1853 - val_accuracy: 0.9578
# Epoch 156/500
# 30/30 [==============================] - 17s 568ms/step - loss: 0.0978 - accuracy: 0.9621 - val_loss: 0.1959 - val_accuracy: 0.9518
# Epoch 157/500
# 30/30 [==============================] - 17s 563ms/step - loss: 0.0919 - accuracy: 0.9672 - val_loss: 0.1990 - val_accuracy: 0.9470
# Epoch 158/500
# 30/30 [==============================] - 16s 514ms/step - loss: 0.0828 - accuracy: 0.9676 - val_loss: 0.2127 - val_accuracy: 0.9410
# Epoch 159/500
# 30/30 [==============================] - 17s 576ms/step - loss: 0.0866 - accuracy: 0.9650 - val_loss: 0.1928 - val_accuracy: 0.9566
# Epoch 160/500
# 30/30 [==============================] - 17s 570ms/step - loss: 0.0981 - accuracy: 0.9637 - val_loss: 0.2091 - val_accuracy: 0.9410
# Epoch 161/500
# 30/30 [==============================] - 14s 484ms/step - loss: 0.0927 - accuracy: 0.9674 - val_loss: 0.1805 - val_accuracy: 0.9530
# Epoch 162/500
# 30/30 [==============================] - 18s 590ms/step - loss: 0.0826 - accuracy: 0.9664 - val_loss: 0.2315 - val_accuracy: 0.9398
# Epoch 163/500
# 30/30 [==============================] - 19s 639ms/step - loss: 0.0910 - accuracy: 0.9644 - val_loss: 0.2211 - val_accuracy: 0.9386
# Epoch 164/500
# 30/30 [==============================] - 17s 568ms/step - loss: 0.0886 - accuracy: 0.9668 - val_loss: 0.2207 - val_accuracy: 0.9398
# Epoch 165/500
# 30/30 [==============================] - 18s 617ms/step - loss: 0.0860 - accuracy: 0.9657 - val_loss: 0.2101 - val_accuracy: 0.9470
# Epoch 166/500
# 30/30 [==============================] - 15s 511ms/step - loss: 0.0746 - accuracy: 0.9725 - val_loss: 0.2233 - val_accuracy: 0.9434
# Epoch 167/500
# 30/30 [==============================] - 18s 605ms/step - loss: 0.0795 - accuracy: 0.9696 - val_loss: 0.1973 - val_accuracy: 0.9554
# Epoch 168/500
# 30/30 [==============================] - 15s 517ms/step - loss: 0.1146 - accuracy: 0.9583 - val_loss: 0.2481 - val_accuracy: 0.9301
# Epoch 169/500
# 30/30 [==============================] - 15s 501ms/step - loss: 0.1310 - accuracy: 0.9522 - val_loss: 0.1955 - val_accuracy: 0.9434
# Epoch 170/500
# 30/30 [==============================] - 17s 556ms/step - loss: 0.1306 - accuracy: 0.9537 - val_loss: 0.1836 - val_accuracy: 0.9542
# Epoch 171/500
# 30/30 [==============================] - 17s 589ms/step - loss: 0.0975 - accuracy: 0.9612 - val_loss: 0.1878 - val_accuracy: 0.9470
# Epoch 172/500
# 30/30 [==============================] - 17s 574ms/step - loss: 0.0786 - accuracy: 0.9717 - val_loss: 0.2233 - val_accuracy: 0.9506
# Epoch 173/500
# 30/30 [==============================] - 15s 505ms/step - loss: 0.0801 - accuracy: 0.9713 - val_loss: 0.2195 - val_accuracy: 0.9434
# Epoch 174/500
# 30/30 [==============================] - 18s 603ms/step - loss: 0.1062 - accuracy: 0.9633 - val_loss: 0.2240 - val_accuracy: 0.9337
# Epoch 175/500
# 30/30 [==============================] - 15s 501ms/step - loss: 0.0819 - accuracy: 0.9704 - val_loss: 0.2535 - val_accuracy: 0.9410
# Epoch 176/500
# 30/30 [==============================] - 17s 565ms/step - loss: 0.0765 - accuracy: 0.9704 - val_loss: 0.3046 - val_accuracy: 0.9253
# Epoch 177/500
# 30/30 [==============================] - 17s 573ms/step - loss: 0.3220 - accuracy: 0.9042 - val_loss: 0.2307 - val_accuracy: 0.9301
# Epoch 178/500
# 30/30 [==============================] - 15s 496ms/step - loss: 0.1479 - accuracy: 0.9456 - val_loss: 0.1916 - val_accuracy: 0.9422
# Epoch 179/500
# 30/30 [==============================] - 15s 502ms/step - loss: 0.0940 - accuracy: 0.9653 - val_loss: 0.2186 - val_accuracy: 0.9434
# Epoch 180/500
# 30/30 [==============================] - 16s 533ms/step - loss: 0.0931 - accuracy: 0.9645 - val_loss: 0.1880 - val_accuracy: 0.9494
# Epoch 181/500
# 30/30 [==============================] - 15s 495ms/step - loss: 0.0809 - accuracy: 0.9672 - val_loss: 0.1713 - val_accuracy: 0.9530
# Epoch 182/500
# 30/30 [==============================] - 18s 592ms/step - loss: 0.0775 - accuracy: 0.9701 - val_loss: 0.2270 - val_accuracy: 0.9422
# Epoch 183/500
# 30/30 [==============================] - 16s 527ms/step - loss: 0.0858 - accuracy: 0.9648 - val_loss: 0.2108 - val_accuracy: 0.9470
# Epoch 184/500
# 30/30 [==============================] - 16s 545ms/step - loss: 0.0656 - accuracy: 0.9747 - val_loss: 0.2106 - val_accuracy: 0.9482
# Epoch 185/500
# 30/30 [==============================] - 15s 520ms/step - loss: 0.0712 - accuracy: 0.9709 - val_loss: 0.2046 - val_accuracy: 0.9494
# Epoch 186/500
# 30/30 [==============================] - 15s 514ms/step - loss: 0.0719 - accuracy: 0.9736 - val_loss: 0.2124 - val_accuracy: 0.9506
# Epoch 187/500
# 30/30 [==============================] - 18s 598ms/step - loss: 0.0729 - accuracy: 0.9725 - val_loss: 0.2695 - val_accuracy: 0.9313
# Epoch 188/500
# 30/30 [==============================] - 15s 495ms/step - loss: 0.0777 - accuracy: 0.9701 - val_loss: 0.2085 - val_accuracy: 0.9506
# Epoch 189/500
# 30/30 [==============================] - 16s 540ms/step - loss: 0.0926 - accuracy: 0.9650 - val_loss: 0.2750 - val_accuracy: 0.9373
# Epoch 190/500
# 30/30 [==============================] - 16s 533ms/step - loss: 0.1110 - accuracy: 0.9613 - val_loss: 0.1691 - val_accuracy: 0.9518
# Epoch 191/500
# 30/30 [==============================] - 21s 715ms/step - loss: 0.0846 - accuracy: 0.9680 - val_loss: 0.2239 - val_accuracy: 0.9398
# Epoch 192/500
# 30/30 [==============================] - 16s 553ms/step - loss: 0.0900 - accuracy: 0.9674 - val_loss: 0.2449 - val_accuracy: 0.9325
# Epoch 193/500
# 30/30 [==============================] - 16s 554ms/step - loss: 0.0781 - accuracy: 0.9716 - val_loss: 0.2266 - val_accuracy: 0.9458
# Epoch 194/500
# 30/30 [==============================] - 16s 552ms/step - loss: 0.0977 - accuracy: 0.9657 - val_loss: 0.2146 - val_accuracy: 0.9434
# Epoch 195/500
# 30/30 [==============================] - 17s 556ms/step - loss: 0.0800 - accuracy: 0.9708 - val_loss: 0.2026 - val_accuracy: 0.9554
# Epoch 196/500
# 30/30 [==============================] - 19s 626ms/step - loss: 0.0795 - accuracy: 0.9701 - val_loss: 0.2092 - val_accuracy: 0.9518
# Epoch 197/500
# 30/30 [==============================] - 16s 541ms/step - loss: 0.0710 - accuracy: 0.9727 - val_loss: 0.1873 - val_accuracy: 0.9554
# Epoch 198/500
# 30/30 [==============================] - 17s 581ms/step - loss: 0.0608 - accuracy: 0.9775 - val_loss: 0.2199 - val_accuracy: 0.9422
# Epoch 199/500
# 30/30 [==============================] - 17s 578ms/step - loss: 0.0821 - accuracy: 0.9696 - val_loss: 0.1854 - val_accuracy: 0.9470
# Epoch 200/500
# 30/30 [==============================] - 16s 549ms/step - loss: 0.0680 - accuracy: 0.9747 - val_loss: 0.2510 - val_accuracy: 0.9361
# Epoch 201/500
# 30/30 [==============================] - 15s 485ms/step - loss: 0.0880 - accuracy: 0.9693 - val_loss: 0.2120 - val_accuracy: 0.9530
# Epoch 202/500
# 30/30 [==============================] - 17s 575ms/step - loss: 0.0645 - accuracy: 0.9755 - val_loss: 0.2317 - val_accuracy: 0.9518
# Epoch 203/500
# 30/30 [==============================] - 15s 512ms/step - loss: 0.0712 - accuracy: 0.9745 - val_loss: 0.1994 - val_accuracy: 0.9518
# Epoch 204/500
# 30/30 [==============================] - 17s 558ms/step - loss: 0.0762 - accuracy: 0.9713 - val_loss: 0.2437 - val_accuracy: 0.9422
# Epoch 205/500
# 30/30 [==============================] - 19s 631ms/step - loss: 0.0753 - accuracy: 0.9711 - val_loss: 0.2512 - val_accuracy: 0.9434
# Epoch 206/500
# 30/30 [==============================] - 18s 605ms/step - loss: 0.0744 - accuracy: 0.9740 - val_loss: 0.2629 - val_accuracy: 0.9434
# Epoch 207/500
# 30/30 [==============================] - 18s 600ms/step - loss: 0.0828 - accuracy: 0.9689 - val_loss: 0.3402 - val_accuracy: 0.9277
# Epoch 208/500
# 30/30 [==============================] - 16s 521ms/step - loss: 0.0900 - accuracy: 0.9678 - val_loss: 0.2203 - val_accuracy: 0.9530
# Epoch 209/500
# 30/30 [==============================] - 14s 484ms/step - loss: 0.0649 - accuracy: 0.9758 - val_loss: 0.2744 - val_accuracy: 0.9398
# Epoch 210/500
# 30/30 [==============================] - 16s 550ms/step - loss: 0.0773 - accuracy: 0.9720 - val_loss: 0.1927 - val_accuracy: 0.9530
# Epoch 211/500
# 30/30 [==============================] - 16s 552ms/step - loss: 0.0738 - accuracy: 0.9749 - val_loss: 0.2321 - val_accuracy: 0.9482
# Epoch 212/500
# 30/30 [==============================] - 17s 580ms/step - loss: 0.0918 - accuracy: 0.9687 - val_loss: 0.2126 - val_accuracy: 0.9530
# Epoch 213/500
# 30/30 [==============================] - 16s 523ms/step - loss: 0.1063 - accuracy: 0.9603 - val_loss: 0.1715 - val_accuracy: 0.9590
# Epoch 214/500
# 30/30 [==============================] - 16s 522ms/step - loss: 0.1174 - accuracy: 0.9561 - val_loss: 0.2019 - val_accuracy: 0.9422
# Epoch 215/500
# 30/30 [==============================] - 15s 520ms/step - loss: 0.0790 - accuracy: 0.9691 - val_loss: 0.2530 - val_accuracy: 0.9361
# Epoch 216/500
# 30/30 [==============================] - 18s 619ms/step - loss: 0.0758 - accuracy: 0.9700 - val_loss: 0.2233 - val_accuracy: 0.9482
# Epoch 217/500
# 30/30 [==============================] - 14s 464ms/step - loss: 0.0734 - accuracy: 0.9728 - val_loss: 0.1896 - val_accuracy: 0.9578
# Epoch 218/500
# 30/30 [==============================] - 17s 588ms/step - loss: 0.0675 - accuracy: 0.9747 - val_loss: 0.1861 - val_accuracy: 0.9530
# Epoch 219/500
# 30/30 [==============================] - 17s 575ms/step - loss: 0.0610 - accuracy: 0.9771 - val_loss: 0.2178 - val_accuracy: 0.9590
# Epoch 220/500
# 30/30 [==============================] - 18s 589ms/step - loss: 0.0603 - accuracy: 0.9778 - val_loss: 0.2265 - val_accuracy: 0.9458
# Epoch 221/500
# 30/30 [==============================] - 17s 556ms/step - loss: 0.0879 - accuracy: 0.9662 - val_loss: 0.2521 - val_accuracy: 0.9434
# Epoch 222/500
# 30/30 [==============================] - 19s 653ms/step - loss: 0.0853 - accuracy: 0.9692 - val_loss: 0.2425 - val_accuracy: 0.9494
# Epoch 223/500
# 30/30 [==============================] - 16s 525ms/step - loss: 0.0781 - accuracy: 0.9720 - val_loss: 0.2024 - val_accuracy: 0.9482
# Epoch 224/500
# 30/30 [==============================] - 14s 468ms/step - loss: 0.0632 - accuracy: 0.9770 - val_loss: 0.2004 - val_accuracy: 0.9482
# Epoch 225/500
# 30/30 [==============================] - 17s 572ms/step - loss: 0.1009 - accuracy: 0.9672 - val_loss: 0.2659 - val_accuracy: 0.9458
# Epoch 226/500
# 30/30 [==============================] - 20s 656ms/step - loss: 0.0837 - accuracy: 0.9685 - val_loss: 0.2036 - val_accuracy: 0.9566
# Epoch 227/500
# 30/30 [==============================] - 16s 552ms/step - loss: 0.0730 - accuracy: 0.9745 - val_loss: 0.2712 - val_accuracy: 0.9265
# Epoch 228/500
# 30/30 [==============================] - 14s 484ms/step - loss: 0.0819 - accuracy: 0.9683 - val_loss: 0.2098 - val_accuracy: 0.9470
# Epoch 229/500
# 30/30 [==============================] - 17s 557ms/step - loss: 0.0620 - accuracy: 0.9770 - val_loss: 0.2414 - val_accuracy: 0.9458
# Epoch 230/500
# 30/30 [==============================] - 15s 509ms/step - loss: 0.0744 - accuracy: 0.9743 - val_loss: 0.2286 - val_accuracy: 0.9542
# Epoch 231/500
# 30/30 [==============================] - 17s 559ms/step - loss: 0.0700 - accuracy: 0.9737 - val_loss: 0.1967 - val_accuracy: 0.9482
# Epoch 232/500
# 30/30 [==============================] - 15s 495ms/step - loss: 0.0630 - accuracy: 0.9762 - val_loss: 0.2251 - val_accuracy: 0.9373
# Epoch 233/500
# 30/30 [==============================] - 15s 498ms/step - loss: 0.0750 - accuracy: 0.9747 - val_loss: 0.2107 - val_accuracy: 0.9506
# Epoch 234/500
# 30/30 [==============================] - 16s 554ms/step - loss: 0.0799 - accuracy: 0.9715 - val_loss: 0.2278 - val_accuracy: 0.9410
# Epoch 235/500
# 30/30 [==============================] - 16s 538ms/step - loss: 0.0730 - accuracy: 0.9749 - val_loss: 0.1952 - val_accuracy: 0.9542
# Epoch 236/500
# 30/30 [==============================] - 16s 533ms/step - loss: 0.0581 - accuracy: 0.9787 - val_loss: 0.2054 - val_accuracy: 0.9590
# Epoch 237/500
# 30/30 [==============================] - 17s 576ms/step - loss: 0.0692 - accuracy: 0.9744 - val_loss: 0.2381 - val_accuracy: 0.9506
# Epoch 238/500
# 30/30 [==============================] - 19s 657ms/step - loss: 0.0631 - accuracy: 0.9759 - val_loss: 0.2165 - val_accuracy: 0.9410
# Epoch 239/500
# 30/30 [==============================] - 18s 623ms/step - loss: 0.0634 - accuracy: 0.9764 - val_loss: 0.2264 - val_accuracy: 0.9494
# Epoch 240/500
# 30/30 [==============================] - 19s 638ms/step - loss: 0.0730 - accuracy: 0.9741 - val_loss: 0.2063 - val_accuracy: 0.9482
# Epoch 241/500
# 30/30 [==============================] - 18s 619ms/step - loss: 0.0711 - accuracy: 0.9737 - val_loss: 0.1897 - val_accuracy: 0.9554
# Epoch 242/500
# 30/30 [==============================] - 15s 506ms/step - loss: 0.0796 - accuracy: 0.9709 - val_loss: 0.2524 - val_accuracy: 0.9482
# Epoch 243/500
# 30/30 [==============================] - 16s 533ms/step - loss: 0.1184 - accuracy: 0.9590 - val_loss: 0.2268 - val_accuracy: 0.9458
# Epoch 244/500
# 30/30 [==============================] - 17s 570ms/step - loss: 0.0802 - accuracy: 0.9700 - val_loss: 0.2770 - val_accuracy: 0.9361
# Epoch 245/500
# 30/30 [==============================] - 17s 568ms/step - loss: 0.0739 - accuracy: 0.9736 - val_loss: 0.1931 - val_accuracy: 0.9518
# Epoch 246/500
# 30/30 [==============================] - 17s 587ms/step - loss: 0.0664 - accuracy: 0.9754 - val_loss: 0.2202 - val_accuracy: 0.9530
# Epoch 247/500
# 30/30 [==============================] - 18s 602ms/step - loss: 0.0671 - accuracy: 0.9771 - val_loss: 0.1909 - val_accuracy: 0.9458
# Epoch 248/500
# 30/30 [==============================] - 16s 535ms/step - loss: 0.0681 - accuracy: 0.9754 - val_loss: 0.2288 - val_accuracy: 0.9458
# Epoch 249/500
# 30/30 [==============================] - 16s 552ms/step - loss: 0.0551 - accuracy: 0.9787 - val_loss: 0.2308 - val_accuracy: 0.9446
# Epoch 250/500
# 30/30 [==============================] - 15s 499ms/step - loss: 0.1446 - accuracy: 0.9545 - val_loss: 0.2327 - val_accuracy: 0.9373
# Epoch 251/500
# 30/30 [==============================] - 16s 550ms/step - loss: 0.0882 - accuracy: 0.9681 - val_loss: 0.1932 - val_accuracy: 0.9422
# Epoch 252/500
# 30/30 [==============================] - 15s 499ms/step - loss: 0.0681 - accuracy: 0.9737 - val_loss: 0.1783 - val_accuracy: 0.9530
# Epoch 253/500
# 30/30 [==============================] - 14s 478ms/step - loss: 0.0606 - accuracy: 0.9768 - val_loss: 0.2196 - val_accuracy: 0.9482
# Epoch 254/500
# 30/30 [==============================] - 16s 554ms/step - loss: 0.0789 - accuracy: 0.9717 - val_loss: 0.2394 - val_accuracy: 0.9361
# Epoch 255/500
# 30/30 [==============================] - 19s 654ms/step - loss: 0.1019 - accuracy: 0.9620 - val_loss: 0.2275 - val_accuracy: 0.9398
# Epoch 256/500
# 30/30 [==============================] - 19s 650ms/step - loss: 0.0574 - accuracy: 0.9776 - val_loss: 0.2134 - val_accuracy: 0.9506
# Epoch 257/500
# 30/30 [==============================] - 15s 509ms/step - loss: 0.0571 - accuracy: 0.9782 - val_loss: 0.2099 - val_accuracy: 0.9470
# Epoch 258/500
# 30/30 [==============================] - 16s 534ms/step - loss: 0.0682 - accuracy: 0.9771 - val_loss: 0.2294 - val_accuracy: 0.9542
# Epoch 259/500
# 30/30 [==============================] - 18s 601ms/step - loss: 0.0754 - accuracy: 0.9743 - val_loss: 0.2256 - val_accuracy: 0.9458
# Epoch 260/500
# 30/30 [==============================] - 18s 590ms/step - loss: 0.0734 - accuracy: 0.9719 - val_loss: 0.1986 - val_accuracy: 0.9506
# Epoch 261/500
# 30/30 [==============================] - 16s 523ms/step - loss: 0.0562 - accuracy: 0.9790 - val_loss: 0.2218 - val_accuracy: 0.9458
# Epoch 262/500
# 30/30 [==============================] - 16s 533ms/step - loss: 0.0508 - accuracy: 0.9814 - val_loss: 0.2214 - val_accuracy: 0.9458
# Epoch 263/500
# 30/30 [==============================] - 17s 580ms/step - loss: 0.0449 - accuracy: 0.9829 - val_loss: 0.2495 - val_accuracy: 0.9470
# Epoch 264/500
# 30/30 [==============================] - 16s 552ms/step - loss: 0.0575 - accuracy: 0.9778 - val_loss: 0.2189 - val_accuracy: 0.9518
# Epoch 265/500
# 30/30 [==============================] - 16s 533ms/step - loss: 0.0627 - accuracy: 0.9763 - val_loss: 0.2061 - val_accuracy: 0.9458
# Epoch 266/500
# 30/30 [==============================] - 15s 514ms/step - loss: 0.0547 - accuracy: 0.9814 - val_loss: 0.2393 - val_accuracy: 0.9422
# Epoch 267/500
# 30/30 [==============================] - 17s 585ms/step - loss: 0.0682 - accuracy: 0.9762 - val_loss: 0.2911 - val_accuracy: 0.9398
# Epoch 268/500
# 30/30 [==============================] - 16s 541ms/step - loss: 0.0654 - accuracy: 0.9755 - val_loss: 0.2279 - val_accuracy: 0.9434
# Epoch 269/500
# 30/30 [==============================] - 16s 548ms/step - loss: 0.0656 - accuracy: 0.9770 - val_loss: 0.2300 - val_accuracy: 0.9422
# Epoch 270/500
# 30/30 [==============================] - 17s 561ms/step - loss: 0.0958 - accuracy: 0.9669 - val_loss: 0.2276 - val_accuracy: 0.9410
# Epoch 271/500
# 30/30 [==============================] - 15s 519ms/step - loss: 0.0756 - accuracy: 0.9723 - val_loss: 0.2048 - val_accuracy: 0.9506
# Epoch 272/500
# 30/30 [==============================] - 16s 553ms/step - loss: 0.0515 - accuracy: 0.9826 - val_loss: 0.2002 - val_accuracy: 0.9506
# Epoch 273/500
# 30/30 [==============================] - 16s 531ms/step - loss: 0.0620 - accuracy: 0.9767 - val_loss: 0.2161 - val_accuracy: 0.9506
# Epoch 274/500
# 30/30 [==============================] - 14s 484ms/step - loss: 0.0616 - accuracy: 0.9791 - val_loss: 0.2701 - val_accuracy: 0.9434
# Epoch 275/500
# 30/30 [==============================] - 14s 486ms/step - loss: 0.1634 - accuracy: 0.9457 - val_loss: 0.3112 - val_accuracy: 0.9133
# Epoch 276/500
# 30/30 [==============================] - 14s 474ms/step - loss: 0.1323 - accuracy: 0.9591 - val_loss: 0.1735 - val_accuracy: 0.9506
# Epoch 277/500
# 30/30 [==============================] - 17s 558ms/step - loss: 0.0795 - accuracy: 0.9703 - val_loss: 0.2099 - val_accuracy: 0.9470
# Epoch 278/500
# 30/30 [==============================] - 17s 568ms/step - loss: 0.0602 - accuracy: 0.9786 - val_loss: 0.2068 - val_accuracy: 0.9470
# Epoch 279/500
# 30/30 [==============================] - 17s 577ms/step - loss: 0.0519 - accuracy: 0.9812 - val_loss: 0.2281 - val_accuracy: 0.9458
# Epoch 280/500
# 30/30 [==============================] - 15s 519ms/step - loss: 0.0542 - accuracy: 0.9806 - val_loss: 0.2117 - val_accuracy: 0.9494
# Epoch 281/500
# 30/30 [==============================] - 18s 600ms/step - loss: 0.0660 - accuracy: 0.9756 - val_loss: 0.2472 - val_accuracy: 0.9494
# Epoch 282/500
# 30/30 [==============================] - 15s 495ms/step - loss: 0.0592 - accuracy: 0.9779 - val_loss: 0.2214 - val_accuracy: 0.9482
# Epoch 283/500
# 30/30 [==============================] - 15s 502ms/step - loss: 0.0656 - accuracy: 0.9776 - val_loss: 0.1989 - val_accuracy: 0.9530
# Epoch 284/500
# 30/30 [==============================] - 18s 595ms/step - loss: 0.0593 - accuracy: 0.9778 - val_loss: 0.2018 - val_accuracy: 0.9566
# Epoch 285/500
# 30/30 [==============================] - 15s 496ms/step - loss: 0.0457 - accuracy: 0.9861 - val_loss: 0.2288 - val_accuracy: 0.9530
# Epoch 286/500
# 30/30 [==============================] - 16s 551ms/step - loss: 0.0701 - accuracy: 0.9758 - val_loss: 0.2369 - val_accuracy: 0.9506
# Epoch 287/500
# 30/30 [==============================] - 16s 553ms/step - loss: 0.0661 - accuracy: 0.9798 - val_loss: 0.2335 - val_accuracy: 0.9482
# Epoch 288/500
# 30/30 [==============================] - 17s 564ms/step - loss: 0.0510 - accuracy: 0.9826 - val_loss: 0.2287 - val_accuracy: 0.9554
# Epoch 289/500
# 30/30 [==============================] - 15s 515ms/step - loss: 0.0326 - accuracy: 0.9878 - val_loss: 0.2427 - val_accuracy: 0.9542
# Epoch 290/500
# 30/30 [==============================] - 15s 491ms/step - loss: 0.0386 - accuracy: 0.9869 - val_loss: 0.2176 - val_accuracy: 0.9566
# Epoch 291/500
# 30/30 [==============================] - 16s 553ms/step - loss: 0.0474 - accuracy: 0.9845 - val_loss: 0.2777 - val_accuracy: 0.9494
# Epoch 292/500
# 30/30 [==============================] - 18s 587ms/step - loss: 0.0773 - accuracy: 0.9733 - val_loss: 0.2636 - val_accuracy: 0.9398
# Epoch 293/500
# 30/30 [==============================] - 15s 517ms/step - loss: 0.0756 - accuracy: 0.9736 - val_loss: 0.2483 - val_accuracy: 0.9458
# Epoch 294/500
# 30/30 [==============================] - 18s 608ms/step - loss: 0.0505 - accuracy: 0.9819 - val_loss: 0.2268 - val_accuracy: 0.9518
# Epoch 295/500
# 30/30 [==============================] - 16s 548ms/step - loss: 0.0568 - accuracy: 0.9829 - val_loss: 0.2189 - val_accuracy: 0.9542
# Epoch 296/500
# 30/30 [==============================] - 17s 584ms/step - loss: 0.0461 - accuracy: 0.9842 - val_loss: 0.2239 - val_accuracy: 0.9542
# Epoch 297/500
# 30/30 [==============================] - 15s 507ms/step - loss: 0.0571 - accuracy: 0.9787 - val_loss: 0.2206 - val_accuracy: 0.9506
# Epoch 298/500
# 30/30 [==============================] - 17s 566ms/step - loss: 0.0721 - accuracy: 0.9764 - val_loss: 0.2767 - val_accuracy: 0.9410
# Epoch 299/500
# 30/30 [==============================] - 16s 545ms/step - loss: 0.0651 - accuracy: 0.9762 - val_loss: 0.2650 - val_accuracy: 0.9494
# Epoch 300/500
# 30/30 [==============================] - 16s 522ms/step - loss: 0.0717 - accuracy: 0.9780 - val_loss: 0.3020 - val_accuracy: 0.9325
# Epoch 301/500
# 30/30 [==============================] - 16s 523ms/step - loss: 0.0762 - accuracy: 0.9735 - val_loss: 0.2078 - val_accuracy: 0.9566
# Epoch 302/500
# 30/30 [==============================] - 15s 519ms/step - loss: 0.0483 - accuracy: 0.9826 - val_loss: 0.2437 - val_accuracy: 0.9422
# Epoch 303/500
# 30/30 [==============================] - 17s 563ms/step - loss: 0.1178 - accuracy: 0.9638 - val_loss: 0.2060 - val_accuracy: 0.9518
# Epoch 304/500
# 30/30 [==============================] - 15s 505ms/step - loss: 0.0707 - accuracy: 0.9745 - val_loss: 0.2186 - val_accuracy: 0.9470
# Epoch 305/500
# 30/30 [==============================] - 14s 483ms/step - loss: 0.0655 - accuracy: 0.9767 - val_loss: 0.2327 - val_accuracy: 0.9470
# Epoch 306/500
# 30/30 [==============================] - 18s 591ms/step - loss: 0.0516 - accuracy: 0.9800 - val_loss: 0.2253 - val_accuracy: 0.9518
# Epoch 307/500
# 30/30 [==============================] - 15s 518ms/step - loss: 0.0394 - accuracy: 0.9870 - val_loss: 0.2650 - val_accuracy: 0.9386
# Epoch 308/500
# 30/30 [==============================] - 19s 649ms/step - loss: 0.0524 - accuracy: 0.9804 - val_loss: 0.2522 - val_accuracy: 0.9530
# Epoch 309/500
# 30/30 [==============================] - 18s 606ms/step - loss: 0.0604 - accuracy: 0.9780 - val_loss: 0.2153 - val_accuracy: 0.9566
# Epoch 310/500
# 30/30 [==============================] - 16s 531ms/step - loss: 0.0487 - accuracy: 0.9815 - val_loss: 0.2200 - val_accuracy: 0.9518
# Epoch 311/500
# 30/30 [==============================] - 16s 539ms/step - loss: 0.0404 - accuracy: 0.9846 - val_loss: 0.2369 - val_accuracy: 0.9434
# Epoch 312/500
# 30/30 [==============================] - 17s 565ms/step - loss: 0.0532 - accuracy: 0.9815 - val_loss: 0.2339 - val_accuracy: 0.9506
# Epoch 313/500
# 30/30 [==============================] - 16s 551ms/step - loss: 0.0870 - accuracy: 0.9705 - val_loss: 0.2599 - val_accuracy: 0.9373
# Epoch 314/500
# 30/30 [==============================] - 13s 442ms/step - loss: 0.0550 - accuracy: 0.9795 - val_loss: 0.2530 - val_accuracy: 0.9458
# Epoch 315/500
# 30/30 [==============================] - 17s 560ms/step - loss: 0.0749 - accuracy: 0.9751 - val_loss: 0.2028 - val_accuracy: 0.9458
# Epoch 316/500
# 30/30 [==============================] - 16s 553ms/step - loss: 0.0665 - accuracy: 0.9787 - val_loss: 0.2317 - val_accuracy: 0.9446
# Epoch 317/500
# 30/30 [==============================] - 15s 504ms/step - loss: 0.1704 - accuracy: 0.9435 - val_loss: 0.1959 - val_accuracy: 0.9458
# Epoch 318/500
# 30/30 [==============================] - 15s 502ms/step - loss: 0.0966 - accuracy: 0.9658 - val_loss: 0.2174 - val_accuracy: 0.9458
# Epoch 319/500
# 30/30 [==============================] - 17s 582ms/step - loss: 0.0551 - accuracy: 0.9790 - val_loss: 0.1935 - val_accuracy: 0.9578
# Epoch 320/500
# 30/30 [==============================] - 17s 563ms/step - loss: 0.0528 - accuracy: 0.9827 - val_loss: 0.2557 - val_accuracy: 0.9470
# Epoch 321/500
# 30/30 [==============================] - 17s 572ms/step - loss: 0.0590 - accuracy: 0.9794 - val_loss: 0.2494 - val_accuracy: 0.9434
# Epoch 322/500
# 30/30 [==============================] - 16s 528ms/step - loss: 0.0723 - accuracy: 0.9751 - val_loss: 0.2827 - val_accuracy: 0.9277
# Epoch 323/500
# 30/30 [==============================] - 17s 584ms/step - loss: 0.0748 - accuracy: 0.9747 - val_loss: 0.2512 - val_accuracy: 0.9422
# Epoch 324/500
# 30/30 [==============================] - 16s 553ms/step - loss: 0.0487 - accuracy: 0.9833 - val_loss: 0.2334 - val_accuracy: 0.9458
# Epoch 325/500
# 30/30 [==============================] - 15s 486ms/step - loss: 0.0459 - accuracy: 0.9843 - val_loss: 0.1994 - val_accuracy: 0.9566
# Epoch 326/500
# 30/30 [==============================] - 16s 532ms/step - loss: 0.0333 - accuracy: 0.9883 - val_loss: 0.2433 - val_accuracy: 0.9470
# Epoch 327/500
# 30/30 [==============================] - 15s 500ms/step - loss: 0.0314 - accuracy: 0.9893 - val_loss: 0.2605 - val_accuracy: 0.9494
# Epoch 328/500
# 30/30 [==============================] - 18s 619ms/step - loss: 0.0527 - accuracy: 0.9816 - val_loss: 0.2484 - val_accuracy: 0.9494
# Epoch 329/500
# ...
# Epoch 398/500
# 30/30 [==============================] - 13s 450ms/step - loss: 0.0370 - accuracy: 0.9875 - val_loss: 0.2677 - val_accuracy: 0.9554
# Epoch 399/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0496 - accuracy: 0.9822 - val_loss: 0.2607 - val_accuracy: 0.9518
# Epoch 400/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0656 - accuracy: 0.9770 - val_loss: 0.2754 - val_accuracy: 0.9458
# Epoch 401/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0938 - accuracy: 0.9678 - val_loss: 0.4017 - val_accuracy: 0.9217
# Epoch 402/500
# 30/30 [==============================] - 13s 443ms/step - loss: 0.0794 - accuracy: 0.9759 - val_loss: 0.2260 - val_accuracy: 0.9458
# Epoch 403/500
# 30/30 [==============================] - 13s 443ms/step - loss: 0.0444 - accuracy: 0.9831 - val_loss: 0.2290 - val_accuracy: 0.9554
# Epoch 404/500
# 30/30 [==============================] - 15s 489ms/step - loss: 0.0415 - accuracy: 0.9858 - val_loss: 0.3301 - val_accuracy: 0.9422
# Epoch 405/500
# 30/30 [==============================] - 13s 432ms/step - loss: 0.0592 - accuracy: 0.9795 - val_loss: 0.2368 - val_accuracy: 0.9530
# Epoch 406/500
# 30/30 [==============================] - 14s 472ms/step - loss: 0.0388 - accuracy: 0.9865 - val_loss: 0.3223 - val_accuracy: 0.9422
# Epoch 407/500
# 30/30 [==============================] - 13s 432ms/step - loss: 0.0372 - accuracy: 0.9862 - val_loss: 0.2861 - val_accuracy: 0.9470
# Epoch 408/500
# 30/30 [==============================] - 13s 438ms/step - loss: 0.0539 - accuracy: 0.9839 - val_loss: 0.2981 - val_accuracy: 0.9446
# Epoch 409/500
# 30/30 [==============================] - 13s 443ms/step - loss: 0.0649 - accuracy: 0.9791 - val_loss: 0.2718 - val_accuracy: 0.9482
# Epoch 410/500
# 30/30 [==============================] - 13s 438ms/step - loss: 0.0489 - accuracy: 0.9843 - val_loss: 0.2312 - val_accuracy: 0.9470
# Epoch 411/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0402 - accuracy: 0.9875 - val_loss: 0.2365 - val_accuracy: 0.9470
# Epoch 412/500
# 30/30 [==============================] - 13s 434ms/step - loss: 0.0373 - accuracy: 0.9877 - val_loss: 0.2834 - val_accuracy: 0.9422
# Epoch 413/500
# 30/30 [==============================] - 13s 444ms/step - loss: 0.0346 - accuracy: 0.9878 - val_loss: 0.2560 - val_accuracy: 0.9518
# Epoch 414/500
# 30/30 [==============================] - 13s 435ms/step - loss: 0.0298 - accuracy: 0.9890 - val_loss: 0.2533 - val_accuracy: 0.9542
# Epoch 415/500
# 30/30 [==============================] - 13s 448ms/step - loss: 0.0369 - accuracy: 0.9873 - val_loss: 0.3081 - val_accuracy: 0.9446
# Epoch 416/500
# 30/30 [==============================] - 13s 442ms/step - loss: 0.0421 - accuracy: 0.9857 - val_loss: 0.2572 - val_accuracy: 0.9482
# Epoch 417/500
# 30/30 [==============================] - 13s 435ms/step - loss: 0.0478 - accuracy: 0.9838 - val_loss: 0.2768 - val_accuracy: 0.9458
# Epoch 418/500
# 30/30 [==============================] - 13s 435ms/step - loss: 0.0378 - accuracy: 0.9877 - val_loss: 0.2325 - val_accuracy: 0.9470
# Epoch 419/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0408 - accuracy: 0.9859 - val_loss: 0.2990 - val_accuracy: 0.9446
# Epoch 420/500
# 30/30 [==============================] - 13s 441ms/step - loss: 0.0435 - accuracy: 0.9845 - val_loss: 0.2502 - val_accuracy: 0.9530
# Epoch 421/500
# 30/30 [==============================] - 13s 450ms/step - loss: 0.0364 - accuracy: 0.9877 - val_loss: 0.2455 - val_accuracy: 0.9506
# Epoch 422/500
# 30/30 [==============================] - 13s 446ms/step - loss: 0.0657 - accuracy: 0.9783 - val_loss: 0.2843 - val_accuracy: 0.9506
# Epoch 423/500
# 30/30 [==============================] - 13s 444ms/step - loss: 0.0718 - accuracy: 0.9790 - val_loss: 0.2921 - val_accuracy: 0.9398
# Epoch 424/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0567 - accuracy: 0.9833 - val_loss: 0.2857 - val_accuracy: 0.9422
# Epoch 425/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0391 - accuracy: 0.9854 - val_loss: 0.2649 - val_accuracy: 0.9410
# Epoch 426/500
# 30/30 [==============================] - 13s 439ms/step - loss: 0.0355 - accuracy: 0.9878 - val_loss: 0.3013 - val_accuracy: 0.9446
# Epoch 427/500
# 30/30 [==============================] - 15s 500ms/step - loss: 0.0395 - accuracy: 0.9859 - val_loss: 0.2922 - val_accuracy: 0.9434
# Epoch 428/500
# 30/30 [==============================] - 13s 441ms/step - loss: 0.0395 - accuracy: 0.9858 - val_loss: 0.2908 - val_accuracy: 0.9386
# Epoch 429/500
# 30/30 [==============================] - 13s 442ms/step - loss: 0.0461 - accuracy: 0.9855 - val_loss: 0.2983 - val_accuracy: 0.9446
# Epoch 430/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0323 - accuracy: 0.9891 - val_loss: 0.3647 - val_accuracy: 0.9325
# Epoch 431/500
# 30/30 [==============================] - 13s 433ms/step - loss: 0.0512 - accuracy: 0.9850 - val_loss: 0.2896 - val_accuracy: 0.9518
# Epoch 432/500
# 30/30 [==============================] - 13s 445ms/step - loss: 0.0482 - accuracy: 0.9846 - val_loss: 0.3826 - val_accuracy: 0.9229
# Epoch 433/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0665 - accuracy: 0.9780 - val_loss: 0.2576 - val_accuracy: 0.9434
# Epoch 434/500
# 30/30 [==============================] - 14s 453ms/step - loss: 0.0539 - accuracy: 0.9819 - val_loss: 0.2557 - val_accuracy: 0.9434
# Epoch 435/500
# 30/30 [==============================] - 13s 439ms/step - loss: 0.0594 - accuracy: 0.9816 - val_loss: 0.2776 - val_accuracy: 0.9386
# Epoch 436/500
# 30/30 [==============================] - 13s 445ms/step - loss: 0.0487 - accuracy: 0.9837 - val_loss: 0.2933 - val_accuracy: 0.9373
# Epoch 437/500
# 30/30 [==============================] - 13s 448ms/step - loss: 0.0473 - accuracy: 0.9839 - val_loss: 0.2991 - val_accuracy: 0.9422
# Epoch 438/500
# 30/30 [==============================] - 13s 449ms/step - loss: 0.0593 - accuracy: 0.9786 - val_loss: 0.2923 - val_accuracy: 0.9373
# Epoch 439/500
# 30/30 [==============================] - 13s 438ms/step - loss: 0.0435 - accuracy: 0.9866 - val_loss: 0.2544 - val_accuracy: 0.9446
# Epoch 440/500
# 30/30 [==============================] - 13s 434ms/step - loss: 0.0316 - accuracy: 0.9909 - val_loss: 0.2659 - val_accuracy: 0.9482
# Epoch 441/500
# 30/30 [==============================] - 13s 445ms/step - loss: 0.0364 - accuracy: 0.9885 - val_loss: 0.2473 - val_accuracy: 0.9494
# Epoch 442/500
# 30/30 [==============================] - 13s 442ms/step - loss: 0.0398 - accuracy: 0.9875 - val_loss: 0.2623 - val_accuracy: 0.9530
# Epoch 443/500
# 30/30 [==============================] - 13s 433ms/step - loss: 0.0323 - accuracy: 0.9896 - val_loss: 0.2367 - val_accuracy: 0.9506
# Epoch 444/500
# 30/30 [==============================] - 13s 445ms/step - loss: 0.0853 - accuracy: 0.9725 - val_loss: 0.2487 - val_accuracy: 0.9410
# Epoch 445/500
# 30/30 [==============================] - 13s 440ms/step - loss: 0.0611 - accuracy: 0.9795 - val_loss: 0.2904 - val_accuracy: 0.9434
# Epoch 446/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0493 - accuracy: 0.9850 - val_loss: 0.2628 - val_accuracy: 0.9446
# Epoch 447/500
# 30/30 [==============================] - 13s 434ms/step - loss: 0.0451 - accuracy: 0.9862 - val_loss: 0.2857 - val_accuracy: 0.9446
# Epoch 448/500
# 30/30 [==============================] - 14s 459ms/step - loss: 0.1325 - accuracy: 0.9601 - val_loss: 0.2951 - val_accuracy: 0.9313
# Epoch 449/500
# 30/30 [==============================] - 14s 463ms/step - loss: 0.0643 - accuracy: 0.9787 - val_loss: 0.2949 - val_accuracy: 0.9386
# Epoch 450/500
# 30/30 [==============================] - 13s 435ms/step - loss: 0.0557 - accuracy: 0.9808 - val_loss: 0.2708 - val_accuracy: 0.9422
# Epoch 451/500
# 30/30 [==============================] - 13s 448ms/step - loss: 0.0544 - accuracy: 0.9826 - val_loss: 0.2654 - val_accuracy: 0.9422
# Epoch 452/500
# 30/30 [==============================] - 13s 447ms/step - loss: 0.0397 - accuracy: 0.9866 - val_loss: 0.2792 - val_accuracy: 0.9446
# Epoch 453/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0801 - accuracy: 0.9739 - val_loss: 0.3437 - val_accuracy: 0.9337
# Epoch 454/500
# 30/30 [==============================] - 13s 446ms/step - loss: 0.0900 - accuracy: 0.9693 - val_loss: 0.2104 - val_accuracy: 0.9470
# Epoch 455/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0438 - accuracy: 0.9845 - val_loss: 0.2746 - val_accuracy: 0.9494
# Epoch 456/500
# 30/30 [==============================] - 13s 452ms/step - loss: 0.0934 - accuracy: 0.9711 - val_loss: 0.2815 - val_accuracy: 0.9398
# Epoch 457/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0767 - accuracy: 0.9758 - val_loss: 0.2701 - val_accuracy: 0.9422
# Epoch 458/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0423 - accuracy: 0.9851 - val_loss: 0.2374 - val_accuracy: 0.9494
# Epoch 459/500
# 30/30 [==============================] - 13s 446ms/step - loss: 0.0317 - accuracy: 0.9909 - val_loss: 0.2291 - val_accuracy: 0.9518
# Epoch 460/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0275 - accuracy: 0.9909 - val_loss: 0.2359 - val_accuracy: 0.9506
# Epoch 461/500
# 30/30 [==============================] - 13s 446ms/step - loss: 0.0463 - accuracy: 0.9838 - val_loss: 0.2662 - val_accuracy: 0.9373
# Epoch 462/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0408 - accuracy: 0.9863 - val_loss: 0.2434 - val_accuracy: 0.9542
# Epoch 463/500
# 30/30 [==============================] - 13s 447ms/step - loss: 0.0272 - accuracy: 0.9906 - val_loss: 0.2708 - val_accuracy: 0.9506
# Epoch 464/500
# 30/30 [==============================] - 13s 435ms/step - loss: 0.0326 - accuracy: 0.9896 - val_loss: 0.2353 - val_accuracy: 0.9458
# Epoch 465/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0319 - accuracy: 0.9885 - val_loss: 0.2558 - val_accuracy: 0.9482
# Epoch 466/500
# 30/30 [==============================] - 15s 497ms/step - loss: 0.0365 - accuracy: 0.9881 - val_loss: 0.2752 - val_accuracy: 0.9470
# Epoch 467/500
# 30/30 [==============================] - 13s 438ms/step - loss: 0.0345 - accuracy: 0.9890 - val_loss: 0.2675 - val_accuracy: 0.9518
# Epoch 468/500
# 30/30 [==============================] - 13s 443ms/step - loss: 0.0560 - accuracy: 0.9811 - val_loss: 0.3110 - val_accuracy: 0.9373
# Epoch 469/500
# 30/30 [==============================] - 13s 447ms/step - loss: 0.0604 - accuracy: 0.9796 - val_loss: 0.2304 - val_accuracy: 0.9566
# Epoch 470/500
# 30/30 [==============================] - 13s 452ms/step - loss: 0.0403 - accuracy: 0.9873 - val_loss: 0.2571 - val_accuracy: 0.9518
# Epoch 471/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0343 - accuracy: 0.9871 - val_loss: 0.2320 - val_accuracy: 0.9554
# Epoch 472/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0465 - accuracy: 0.9858 - val_loss: 0.3039 - val_accuracy: 0.9422
# Epoch 473/500
# 30/30 [==============================] - 13s 447ms/step - loss: 0.0502 - accuracy: 0.9841 - val_loss: 0.3309 - val_accuracy: 0.9301
# Epoch 474/500
# 30/30 [==============================] - 13s 443ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 0.3044 - val_accuracy: 0.9446
# Epoch 475/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0632 - accuracy: 0.9804 - val_loss: 0.2784 - val_accuracy: 0.9337
# Epoch 476/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0494 - accuracy: 0.9831 - val_loss: 0.3172 - val_accuracy: 0.9361
# Epoch 477/500
# 30/30 [==============================] - 13s 444ms/step - loss: 0.0570 - accuracy: 0.9822 - val_loss: 0.2624 - val_accuracy: 0.9494
# Epoch 478/500
# 30/30 [==============================] - 13s 449ms/step - loss: 0.0405 - accuracy: 0.9869 - val_loss: 0.2421 - val_accuracy: 0.9506
# Epoch 479/500
# 30/30 [==============================] - 13s 447ms/step - loss: 0.0314 - accuracy: 0.9877 - val_loss: 0.3423 - val_accuracy: 0.9386
# Epoch 480/500
# 30/30 [==============================] - 13s 445ms/step - loss: 0.0379 - accuracy: 0.9889 - val_loss: 0.2513 - val_accuracy: 0.9494
# Epoch 481/500
# 30/30 [==============================] - 13s 439ms/step - loss: 0.0354 - accuracy: 0.9879 - val_loss: 0.2489 - val_accuracy: 0.9530
# Epoch 482/500
# 30/30 [==============================] - 14s 453ms/step - loss: 0.0407 - accuracy: 0.9877 - val_loss: 0.3066 - val_accuracy: 0.9398
# Epoch 483/500
# 30/30 [==============================] - 13s 434ms/step - loss: 0.0378 - accuracy: 0.9867 - val_loss: 0.2646 - val_accuracy: 0.9542
# Epoch 484/500
# 30/30 [==============================] - 13s 448ms/step - loss: 0.0310 - accuracy: 0.9891 - val_loss: 0.4417 - val_accuracy: 0.9265
# Epoch 485/500
# 30/30 [==============================] - 13s 446ms/step - loss: 0.0888 - accuracy: 0.9747 - val_loss: 0.3387 - val_accuracy: 0.9301
# Epoch 486/500
# 30/30 [==============================] - 13s 441ms/step - loss: 0.0737 - accuracy: 0.9747 - val_loss: 0.3216 - val_accuracy: 0.9361
# Epoch 487/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0451 - accuracy: 0.9838 - val_loss: 0.2932 - val_accuracy: 0.9398
# Epoch 488/500
# 30/30 [==============================] - 13s 436ms/step - loss: 0.0428 - accuracy: 0.9866 - val_loss: 0.2757 - val_accuracy: 0.9470
# Epoch 489/500
# 30/30 [==============================] - 13s 439ms/step - loss: 0.0371 - accuracy: 0.9890 - val_loss: 0.2708 - val_accuracy: 0.9518
# Epoch 490/500
# 30/30 [==============================] - 13s 442ms/step - loss: 0.0462 - accuracy: 0.9851 - val_loss: 0.2696 - val_accuracy: 0.9446
# Epoch 491/500
# 30/30 [==============================] - 13s 431ms/step - loss: 0.0403 - accuracy: 0.9854 - val_loss: 0.2898 - val_accuracy: 0.9494
# Epoch 492/500
# 30/30 [==============================] - 15s 496ms/step - loss: 0.0662 - accuracy: 0.9798 - val_loss: 0.2710 - val_accuracy: 0.9446
# Epoch 493/500
# 30/30 [==============================] - 13s 445ms/step - loss: 0.0413 - accuracy: 0.9874 - val_loss: 0.2677 - val_accuracy: 0.9470
# Epoch 494/500
# 30/30 [==============================] - 13s 437ms/step - loss: 0.0346 - accuracy: 0.9875 - val_loss: 0.2767 - val_accuracy: 0.9482
# Epoch 495/500
# 30/30 [==============================] - 13s 438ms/step - loss: 0.0218 - accuracy: 0.9914 - val_loss: 0.3059 - val_accuracy: 0.9398
# Epoch 496/500
# 30/30 [==============================] - 13s 435ms/step - loss: 0.0274 - accuracy: 0.9916 - val_loss: 0.4357 - val_accuracy: 0.9289
# Epoch 497/500
# 30/30 [==============================] - 13s 430ms/step - loss: 0.0573 - accuracy: 0.9829 - val_loss: 0.3984 - val_accuracy: 0.9277
# Epoch 498/500
# 30/30 [==============================] - 13s 435ms/step - loss: 0.0487 - accuracy: 0.9849 - val_loss: 0.3855 - val_accuracy: 0.9325
# Epoch 499/500
# 30/30 [==============================] - 13s 440ms/step - loss: 0.0715 - accuracy: 0.9762 - val_loss: 0.2639 - val_accuracy: 0.9410
# Epoch 500/500
# 30/30 [==============================] - 13s 431ms/step - loss: 0.0350 - accuracy: 0.9871 - val_loss: 0.2613 - val_accuracy: 0.9458
# 8/8 [==============================] - 1s 81ms/step - loss: 0.2470 - accuracy: 0.9490
# Test loss: 0.24702142179012299
# Test accuracy: 0.9490238428115845
# 922it [00:00, 10654.56it/s]
# Confusion Matrix
# [[ 47   0   0   0   0   0]
#  [  0  72   1   0   2   5]
#  [  0   2 515   0   6   0]
#  [  0   2   0  77   6   8]
#  [  0   1   1   1  97   0]
#  [  0   4   0   5   3  67]]
#                 precision    recall  f1-score   support
#
# Broncheostasis       1.00      1.00      1.00        47
#  Bronchiolitis       0.89      0.90      0.89        80
#           COPD       1.00      0.98      0.99       523
#        Healthy       0.93      0.83      0.87        93
#      Pneumonia       0.85      0.97      0.91       100
#           URTI       0.84      0.85      0.84        79
#
#       accuracy                           0.95       922
#      macro avg       0.92      0.92      0.92       922
#   weighted avg       0.95      0.95      0.95       922

# %%
    plt.figure(1)
    plt.figure(figsize=(14,5))
    plt.subplot(121)
    plt.plot(history.history['loss'],'b--')
    plt.plot(history.history['val_loss'],'g--')
    plt.title('Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='best')
 
    plt.subplot(122)
    plt.plot(history.history['accuracy'],'b--')
    plt.plot(history.history['val_accuracy'],'g--')
    plt.title('Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='best')
    plt.show()

# %%
    print("================================================================================================")  
    X_train_1,X_test,Y_train_1,Y_test=train_test_split(X,Y,test_size=0.1,random_state=22)
    results=model.evaluate(X_test,Y_test,batch_size=128,verbose=1)
    print('Test loss:', results[0])
    print('Test accuracy:', results[1])

    predicted=model.predict(X_test,batch_size=60,verbose=0)
    Y_pred=predicted.argmax(axis=-1)
    Y_predicted=pd.DataFrame(Y_test,columns=['Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'])
    Y_ori=[];Broncheostasis_t=0;Bronchiolitis_t=0;COPD_t=0;Healthy_t=0;Pneumonia_t=0;URTI_t=0;
    for index,row in tqdm(Y_predicted.iterrows()):
        if row['Broncheostasis']==1:
          Broncheostasis_t=Broncheostasis_t+1
          Y_ori.append(0)
        elif row['Bronchiolitis']==1:
          Bronchiolitis_t=Bronchiolitis_t+1
          Y_ori.append(1)
        elif row['COPD']==1:
          COPD_t=COPD_t+1
          Y_ori.append(2)
        elif row['Healthy']==1:
          Healthy_t=Healthy_t+1
          Y_ori.append(3)
        elif row['Pneumonia']==1:
          Pneumonia_t=Pneumonia_t+1
          Y_ori.append(4)
        elif row['URTI']==1:
          URTI_t=URTI_t+1
          Y_ori.append(5)

    cm=confusion_matrix(Y_ori,Y_pred)
    print('Confusion Matrix');
    print(cm)
    
    cm_df = pd.DataFrame(cm,index = ['Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'], columns = ['Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'])
    plt.figure(100)
    plt.figure(figsize=(18,4))
    plt.subplot(121)
    sns.heatmap(cm_df,annot=True,cmap="OrRd")
    plt.title('Confusion Matrix')
    plt.ylabel('Actal Values')
    plt.xlabel('Predicted Values')
    
    cm_norm=confusion_matrix(Y_ori,Y_pred,normalize='true')
    cm_df_norm = pd.DataFrame(cm_norm, index = ['Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'],  columns = ['Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'])
    plt.subplot(122)
    sns.heatmap(cm_df_norm,annot=True,cmap="OrRd")
    plt.title('Normalised Confusion Matrix')
    plt.ylabel('Actal Values')
    plt.xlabel('Predicted Values')
    plt.show()
    
    target_names = ['Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI']
    print(classification_report(Y_ori, Y_pred, target_names=target_names))
# Out:
# ================================================================================================
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1225 - accuracy: 0.9685
# Test loss: 0.12253088504076004
# Test accuracy: 0.9685466289520264
# 922it [00:00, 17552.02it/s]
# Confusion Matrix
# [[ 46   2   0   0   0   1]
#  [  0  80   0   1   0   2]
#  [  0   0 500   0   1   0]
#  [  0   2   0  79   2   5]
#  [  0   0   1   4 107   0]
#  [  0   3   0   4   1  81]]
#                 precision    recall  f1-score   support
#
# Broncheostasis       1.00      0.94      0.97        49
#  Bronchiolitis       0.92      0.96      0.94        83
#           COPD       1.00      1.00      1.00       501
#        Healthy       0.90      0.90      0.90        88
#      Pneumonia       0.96      0.96      0.96       112
#           URTI       0.91      0.91      0.91        89
#
#       accuracy                           0.97       922
#      macro avg       0.95      0.94      0.95       922
#   weighted avg       0.97      0.97      0.97       922

# %%
    from pytz import timezone 
    from datetime import datetime
    ind_time = datetime.now(timezone("Asia/Kolkata")).strftime('%Y_%m_%d_%H_%M_%S')
    fold=0;
    # save the plot varriables
    train_loss=history.history['loss']; filepath_tloss=new_loc+'/train_loss_fold_'+ str(fold+1)+'_'+str(ind_time)+'.txt'; np.savetxt(filepath_tloss,train_loss)
    val_loss=history.history['val_loss']; filepath_vloss=new_loc+'/val_loss_fold_'+ str(fold+1)+'_'+str(ind_time)+'.txt'; np.savetxt(filepath_vloss,val_loss)
    acc=history.history['accuracy'];      filepath_tacc=new_loc+'/train_acc_fold_'+ str(fold+1) +'_'+str(ind_time)+'.txt'; np.savetxt(filepath_tacc,acc)
    val_acc=history.history['val_accuracy']; filepath_vacc=new_loc+'/val_acc_fold_'+ str(fold+1)+'_'+str(ind_time)+'.txt'; np.savetxt(filepath_vacc,val_acc)
    # save model
    model.save_weights(new_loc+'/fold_'+str(fold+1)+'_'+str(ind_time)+'.h5')
    print("================================================================================================")
# Out:
# ================================================================================================

# %%
X_train_1,X_test,Y_train_1,Y_test=train_test_split(X,Y,test_size=0.1,random_state=22)
#loading the autoencoder model
from tensorflow.keras.models import Model
import tensorflow as tf
model.load_weights("/content/gdrive/MyDrive/ICBHI_Results/train_on_14_06_22/fold_1_2022_06_14_16_08_50.h5")
#model.load_weights
out_dense= Model(inputs=model.input,outputs=model.get_layer('dense').output)
Y_denseout = out_dense.predict(X_test)
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2,learning_rate='auto',init='random')
Y_embedded = tsne.fit_transform(Y_denseout)
Y_predicted=pd.DataFrame(Y_test,columns=['Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'])
Y_ori=[];Broncheostasis_t=0;Bronchiolitis_t=0;COPD_t=0;Healthy_t=0;Pneumonia_t=0;URTI_t=0;
for index,row in tqdm(Y_predicted.iterrows()):
    if row['Broncheostasis']==1:
      Broncheostasis_t=Broncheostasis_t+1
      Y_ori.append(0)
    elif row['Bronchiolitis']==1:
       Bronchiolitis_t=Bronchiolitis_t+1
       Y_ori.append(1)
    elif row['COPD']==1:
       COPD_t=COPD_t+1
       Y_ori.append(2)
    elif row['Healthy']==1:
       Healthy_t=Healthy_t+1
       Y_ori.append(3)
    elif row['Pneumonia']==1:
       Pneumonia_t=Pneumonia_t+1
       Y_ori.append(4)
    elif row['URTI']==1:
       URTI_t=URTI_t+1
       Y_ori.append(5)
q=np.array(Y_ori)
label_l=[]
for i in range (X_test.shape[0]):
  if q[i]==0:
    label_l.append('Broncheostasis')
  elif q[i]==1:
    label_l.append('Bronchiolitis')
  elif q[i]==2:
    label_l.append('COPD')
  elif q[i]==3:
    label_l.append('Healthy')
  elif q[i]==4:
    label_l.append('Pneumonia')
  elif q[i]==5:
    label_l.append('URTI')

Label_ar=np.array(label_l)
# Out:
# 922it [00:00, 15941.42it/s]

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.scatterplot(Y_embedded[:,0], Y_embedded[:,1], hue=Label_ar)
plt.xlabel("Dimension 1",fontweight ='bold', fontsize = 15);plt.ylabel("Dimenssion 2",fontweight ='bold', fontsize = 15)
plt.title('t-SNE plot After applying Lightweight CNN',fontweight ='bold', fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 't-SNE plot After applying Lightweight CNN')
