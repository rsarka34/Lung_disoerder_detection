# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.figure
from pathlib import Path
import os
import wave
import keras
import seaborn as sns
import librosa
import soundfile as sf
from google.colab import drive
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from numpy import mean
from numpy import std
import tensorflow as tf
from numpy import dstack
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.utils import to_categorical
from scipy.io import wavfile
from tqdm import tqdm
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.applications import *
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from datetime import date
today = date.today()
f_date=today.strftime("%d_%m_%y")
#os.mkdir("/content/gdrive/My Drive/all_disease_classification/train_on_"+(f_date))
new_loc="/content/gdrive/My Drive/all_disease_classification/train_on_"+(f_date)

# %%
import scipy
sig_dict = scipy.io.loadmat('/content/gdrive/MyDrive/all_disease_classification/7class_train_img.mat')
X=sig_dict['train_img']

# %%
labels=pd.read_excel('/content/gdrive/MyDrive/all_disease_classification/Labels.xlsx',header=None)
labels.columns=["Lung Sound"]
class_label_onehot=pd.get_dummies(labels)
Y=np.array(class_label_onehot);
print(X.shape)
print(Y.shape)
# Out:
# (18906, 64, 64, 3)
# (18906, 7)

# %%
custom_early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=100, 
    min_delta=0.001, 
    mode='max'
)

# %%
def mobile_inception(dim, output_neurons, output_activation):
    print("\nTRAINING ON Lightweight MODEL:-")

    
    def block(x, filters, reps):
        for _ in range(reps):
            # for low-level features
            t1 = Conv2D(filters[0], kernel_size = (1,1))(x)
            t1 = LeakyReLU()(t1)

            # for mid-level features
            t2 = DepthwiseConv2D(kernel_size = (3,3), strides = 1, padding = 'same')(x)
            t2 = LeakyReLU()(t2)
            t2 = Conv2D(filters[1], kernel_size = (1,1))(t2)
            t2 = LeakyReLU()(t2)

            # for high-level features
            t3 = DepthwiseConv2D(kernel_size = (5,5), strides = 1, padding = 'same')(x)
            t3 = LeakyReLU()(t3)
            t3 = Conv2D(filters[2], kernel_size = (1,1))(t3)
            t3 = LeakyReLU()(t3)

            # for most-significant features
            t4 = MaxPool2D(pool_size = (3,3), strides = 1, padding = 'same')(x)
            t4 = Conv2D(filters[3], kernel_size = (1,1))(t4)
            t4 = LeakyReLU()(t4)

            x = Concatenate()([t1, t2, t3, t4])
        
        return x
        
        
    input = Input(shape = dim)
    
    k = 16
    
    x = Conv2D(filters = k, kernel_size = (3,3), strides = 2, padding = 'same')(input)
    x = LeakyReLU()(x)
    x = MaxPool2D(pool_size = (3,3), strides = 2, padding = 'same')(x)
    
    x = DepthwiseConv2D(kernel_size = (3,3), strides = 1, padding = 'same')(x)
    x = LeakyReLU()(x)
    x = Conv2D(filters = 2*k, kernel_size = (1,1))(x)
    x = LeakyReLU()(x)
    x = MaxPool2D(pool_size = (2,2), strides = 2)(x)
    
    x = block(x, [k, k, k, k], reps = 2)
    x = MaxPool2D(pool_size = (2,2), strides = 2)(x)
        
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.3)(x)
    x=  Dense(40, 'relu')(x)
    x = Dropout(0.3)(x)
    output = Dense(output_neurons, output_activation)(x)
    
    model = Model(inputs = input, outputs = output)    
    
    return model

# %%
dim = (64,64,3)
output_neurons = 7
output_activation = 'softmax'
from keras import backend as Ke
Ke.clear_session()
model = mobile_inception(dim, output_neurons, output_activation)
#model.summary()
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# TRAINING ON Lightweight MODEL:-

# %%
from pytz import timezone 
from datetime import datetime
import random
from datetime import datetime
import seaborn as sns
from sklearn.metrics import classification_report
id=[12,2,5];batch=256;
for fold in range (3): 
    #p=random.randint(1,42)
    X_train_1=[];X_test=[];Y_train_1=[];Y_test=[];X_train=[];X_val=[];Y_train=[];Y_val=[];
    p=id[fold]
    print('Random_seed_value== '+str(p))
    X_train_1,X_test,Y_train_1,Y_test=train_test_split(X,Y,test_size=0.1,random_state=p)
    X_train,X_val,Y_train,Y_val=train_test_split(X_train_1,Y_train_1,test_size=0.1,random_state=p)
    print("================================================================================================")
    print(f'Fold--------------> {fold+1}')
    from keras import backend as Ke
    Ke.clear_session()
    model = mobile_inception(dim, output_neurons, output_activation)
    opt =tf.keras.optimizers.Adam(learning_rate=0.008) 
    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])

    history = model.fit(X_train, Y_train, batch_size=batch, epochs=400, verbose=1,validation_data=(X_val, Y_val))#,callbacks=[custom_early_stopping])    
    plt.figure(fold+1)
    plt.figure(figsize=(14,5))
    plt.subplot(121)
    plt.plot(history.history['loss'],'b--')
    plt.plot(history.history['val_loss'],'g--')
    plt.title('Loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='best')
 
    plt.subplot(122)
    plt.plot(history.history['accuracy'],'b--')
    plt.plot(history.history['val_accuracy'],'g--')
    plt.title('Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='best')
    plt.show()   

    results=model.evaluate(X_test,Y_test,batch_size=batch,verbose=1)
    print('Test loss:', results[0])
    print('Test accuracy:', results[1])

    predicted=model.predict(X_test,batch_size=batch,verbose=1)
    Y_pred=predicted.argmax(axis=-1)
    Y_pred=predicted.argmax(axis=-1)
    Y_predicted=pd.DataFrame(Y_test,columns=['Asthma','Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'])
    Y_ori=[];Asthma_t=0;Broncheostasis_t=0;Bronchiolitis_t=0;COPD_t=0;Healthy_t=0;Pneumonia_t=0;URTI_t=0;
    for index,row in tqdm(Y_predicted.iterrows()):
        if row['Asthma']==1:
          Asthma_t=Asthma_t+1
          Y_ori.append(0)
        elif row['Broncheostasis']==1:
          Broncheostasis_t=Broncheostasis_t+1
          Y_ori.append(1)
        elif row['Bronchiolitis']==1:
          Bronchiolitis_t=Bronchiolitis_t+1
          Y_ori.append(2)
        elif row['COPD']==1:
          COPD_t=COPD_t+1
          Y_ori.append(3)
        elif row['Healthy']==1:
          Healthy_t=Healthy_t+1
          Y_ori.append(4)
        elif row['Pneumonia']==1:
          Pneumonia_t=Pneumonia_t+1
          Y_ori.append(5)
        elif row['URTI']==1:
          URTI_t=URTI_t+1
          Y_ori.append(6)

    cm=confusion_matrix(Y_ori,Y_pred)
    cm_norm=confusion_matrix(Y_ori,Y_pred,normalize='true')
    print('Confusion Matrix');
    print(cm)
    
    cm_df = pd.DataFrame(cm,index = ['Asthma','Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'], columns = ['Asthma','Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'])
    plt.figure(100+fold)
    plt.figure(figsize=(20,6))
    plt.subplot(121)
    sns.heatmap(cm_df,annot=True,cmap="OrRd")
    plt.title('Confusion Matrix')
    plt.ylabel('Actal Values')
    plt.xlabel('Predicted Values')
    
    cm_df_norm = pd.DataFrame(cm_norm, index = ['Asthma','Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'],  columns = ['Asthma','Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'])
    plt.subplot(122)
    sns.heatmap(cm_df_norm,annot=True,cmap="OrRd")
    plt.title('Normalised Confusion Matrix')
    plt.ylabel('Actal Values')
    plt.xlabel('Predicted Values')
    plt.show()
    
    target_names = ['Asthma','Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI']
    print(classification_report(Y_ori, Y_pred, target_names=target_names))
    
    ind_time = datetime.now(timezone("Asia/Kolkata")).strftime('%Y_%m_%d_%H_%M_%S')

    # save the plot varriables
    train_loss=history.history['loss']; filepath_tloss=new_loc+'/train_loss_fold_'+ str(fold+1)+'_'+str(ind_time)+'.txt'; np.savetxt(filepath_tloss,train_loss)
    val_loss=history.history['val_loss']; filepath_vloss=new_loc+'/val_loss_fold_'+ str(fold+1)+'_'+str(ind_time)+'.txt'; np.savetxt(filepath_vloss,val_loss)
    acc=history.history['accuracy'];      filepath_tacc=new_loc+'/train_acc_fold_'+ str(fold+1) +'_'+str(ind_time)+'.txt'; np.savetxt(filepath_tacc,acc)
    val_acc=history.history['val_accuracy']; filepath_vacc=new_loc+'/val_acc_fold_'+ str(fold+1)+'_'+str(ind_time)+'.txt'; np.savetxt(filepath_vacc,val_acc)
    # save model
    model.save_weights(new_loc+'/fold_'+str(fold+1)+'_'+str(ind_time)+'.h5')
    print("================================================================================================")
# Out:
# Random_seed_value== 12
# ================================================================================================
# Fold--------------> 1
#
# TRAINING ON Lightweight MODEL:-
# Epoch 1/400
# 60/60 [==============================] - 9s 36ms/step - loss: 1.7105 - accuracy: 0.3489 - val_loss: 1.6229 - val_accuracy: 0.3931
# Epoch 2/400
# 60/60 [==============================] - 1s 17ms/step - loss: 1.5799 - accuracy: 0.3851 - val_loss: 1.4907 - val_accuracy: 0.4036
# Epoch 3/400
# 60/60 [==============================] - 1s 17ms/step - loss: 1.3986 - accuracy: 0.4304 - val_loss: 1.2880 - val_accuracy: 0.4988
# Epoch 4/400
# 60/60 [==============================] - 1s 17ms/step - loss: 1.2357 - accuracy: 0.5044 - val_loss: 1.1576 - val_accuracy: 0.5088
# Epoch 5/400
# 60/60 [==============================] - 1s 17ms/step - loss: 1.0998 - accuracy: 0.5673 - val_loss: 0.9669 - val_accuracy: 0.6228
# Epoch 6/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.9864 - accuracy: 0.6156 - val_loss: 0.8290 - val_accuracy: 0.6763
# Epoch 7/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.8987 - accuracy: 0.6490 - val_loss: 0.8128 - val_accuracy: 0.6657
# Epoch 8/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.8447 - accuracy: 0.6703 - val_loss: 0.8028 - val_accuracy: 0.6804
# Epoch 9/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.8065 - accuracy: 0.6860 - val_loss: 0.7896 - val_accuracy: 0.6957
# Epoch 10/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.7627 - accuracy: 0.6957 - val_loss: 0.6861 - val_accuracy: 0.7186
# Epoch 11/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.7629 - accuracy: 0.6940 - val_loss: 0.7478 - val_accuracy: 0.6998
# Epoch 12/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.7266 - accuracy: 0.7115 - val_loss: 0.6990 - val_accuracy: 0.7156
# Epoch 13/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.6966 - accuracy: 0.7204 - val_loss: 0.6098 - val_accuracy: 0.7474
# Epoch 14/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.6722 - accuracy: 0.7347 - val_loss: 0.5960 - val_accuracy: 0.7656
# Epoch 15/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.6730 - accuracy: 0.7330 - val_loss: 0.6005 - val_accuracy: 0.7438
# Epoch 16/400
# 60/60 [==============================] - 1s 22ms/step - loss: 0.6578 - accuracy: 0.7398 - val_loss: 0.5980 - val_accuracy: 0.7620
# Epoch 17/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.6304 - accuracy: 0.7508 - val_loss: 0.5941 - val_accuracy: 0.7562
# Epoch 18/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.6168 - accuracy: 0.7552 - val_loss: 0.5377 - val_accuracy: 0.7967
# Epoch 19/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5931 - accuracy: 0.7620 - val_loss: 0.5110 - val_accuracy: 0.7996
# Epoch 20/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.6224 - accuracy: 0.7569 - val_loss: 0.5252 - val_accuracy: 0.7902
# Epoch 21/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5647 - accuracy: 0.7757 - val_loss: 0.4775 - val_accuracy: 0.8085
# Epoch 22/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5505 - accuracy: 0.7860 - val_loss: 0.5484 - val_accuracy: 0.7761
# Epoch 23/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5738 - accuracy: 0.7730 - val_loss: 0.4872 - val_accuracy: 0.7996
# Epoch 24/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.5419 - accuracy: 0.7857 - val_loss: 0.4708 - val_accuracy: 0.8026
# Epoch 25/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5445 - accuracy: 0.7865 - val_loss: 0.5885 - val_accuracy: 0.7526
# Epoch 26/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5426 - accuracy: 0.7900 - val_loss: 0.4536 - val_accuracy: 0.8220
# Epoch 27/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5117 - accuracy: 0.8022 - val_loss: 0.4458 - val_accuracy: 0.8314
# Epoch 28/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5408 - accuracy: 0.7891 - val_loss: 0.4655 - val_accuracy: 0.8273
# Epoch 29/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.5106 - accuracy: 0.7973 - val_loss: 0.4398 - val_accuracy: 0.8255
# Epoch 30/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4910 - accuracy: 0.8075 - val_loss: 0.4257 - val_accuracy: 0.8249
# Epoch 31/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.4861 - accuracy: 0.8097 - val_loss: 0.4458 - val_accuracy: 0.8243
# Epoch 32/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4975 - accuracy: 0.8071 - val_loss: 0.3975 - val_accuracy: 0.8455
# Epoch 33/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4773 - accuracy: 0.8117 - val_loss: 0.4730 - val_accuracy: 0.8155
# Epoch 34/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4970 - accuracy: 0.8097 - val_loss: 0.4120 - val_accuracy: 0.8343
# Epoch 35/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4687 - accuracy: 0.8220 - val_loss: 0.4606 - val_accuracy: 0.8155
# Epoch 36/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4764 - accuracy: 0.8159 - val_loss: 0.3870 - val_accuracy: 0.8496
# Epoch 37/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4560 - accuracy: 0.8210 - val_loss: 0.4833 - val_accuracy: 0.8032
# Epoch 38/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4666 - accuracy: 0.8158 - val_loss: 0.4141 - val_accuracy: 0.8425
# Epoch 39/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4946 - accuracy: 0.8090 - val_loss: 0.3788 - val_accuracy: 0.8472
# Epoch 40/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4396 - accuracy: 0.8290 - val_loss: 0.3923 - val_accuracy: 0.8431
# Epoch 41/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4278 - accuracy: 0.8332 - val_loss: 0.3708 - val_accuracy: 0.8519
# Epoch 42/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4438 - accuracy: 0.8244 - val_loss: 0.3748 - val_accuracy: 0.8496
# Epoch 43/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4251 - accuracy: 0.8343 - val_loss: 0.3941 - val_accuracy: 0.8378
# Epoch 44/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4383 - accuracy: 0.8327 - val_loss: 0.3628 - val_accuracy: 0.8508
# Epoch 45/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4121 - accuracy: 0.8420 - val_loss: 0.3813 - val_accuracy: 0.8519
# Epoch 46/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4185 - accuracy: 0.8376 - val_loss: 0.4349 - val_accuracy: 0.8349
# Epoch 47/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.4191 - accuracy: 0.8405 - val_loss: 0.3865 - val_accuracy: 0.8373
# Epoch 48/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.4323 - accuracy: 0.8394 - val_loss: 0.3547 - val_accuracy: 0.8543
# Epoch 49/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4166 - accuracy: 0.8390 - val_loss: 0.3706 - val_accuracy: 0.8502
# Epoch 50/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3908 - accuracy: 0.8485 - val_loss: 0.3539 - val_accuracy: 0.8566
# Epoch 51/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4151 - accuracy: 0.8425 - val_loss: 0.3565 - val_accuracy: 0.8649
# Epoch 52/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3849 - accuracy: 0.8526 - val_loss: 0.3431 - val_accuracy: 0.8772
# Epoch 53/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3893 - accuracy: 0.8465 - val_loss: 0.3441 - val_accuracy: 0.8672
# Epoch 54/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3879 - accuracy: 0.8521 - val_loss: 0.3637 - val_accuracy: 0.8596
# Epoch 55/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3917 - accuracy: 0.8503 - val_loss: 0.3101 - val_accuracy: 0.8784
# Epoch 56/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3881 - accuracy: 0.8516 - val_loss: 0.3700 - val_accuracy: 0.8543
# Epoch 57/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3868 - accuracy: 0.8535 - val_loss: 0.3093 - val_accuracy: 0.8872
# Epoch 58/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.3960 - accuracy: 0.8480 - val_loss: 0.3495 - val_accuracy: 0.8619
# Epoch 59/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3582 - accuracy: 0.8623 - val_loss: 0.3170 - val_accuracy: 0.8731
# Epoch 60/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3558 - accuracy: 0.8659 - val_loss: 0.3015 - val_accuracy: 0.8731
# Epoch 61/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.4031 - accuracy: 0.8499 - val_loss: 0.3868 - val_accuracy: 0.8408
# Epoch 62/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3607 - accuracy: 0.8599 - val_loss: 0.3428 - val_accuracy: 0.8566
# Epoch 63/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3804 - accuracy: 0.8525 - val_loss: 0.3134 - val_accuracy: 0.8749
# Epoch 64/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3616 - accuracy: 0.8627 - val_loss: 0.3272 - val_accuracy: 0.8719
# Epoch 65/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3588 - accuracy: 0.8634 - val_loss: 0.3630 - val_accuracy: 0.8531
# Epoch 66/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3823 - accuracy: 0.8533 - val_loss: 0.3205 - val_accuracy: 0.8749
# Epoch 67/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3568 - accuracy: 0.8637 - val_loss: 0.3021 - val_accuracy: 0.8860
# Epoch 68/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3568 - accuracy: 0.8626 - val_loss: 0.3306 - val_accuracy: 0.8684
# Epoch 69/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3692 - accuracy: 0.8578 - val_loss: 0.2850 - val_accuracy: 0.8831
# Epoch 70/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3368 - accuracy: 0.8743 - val_loss: 0.3153 - val_accuracy: 0.8707
# Epoch 71/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.3445 - accuracy: 0.8683 - val_loss: 0.2961 - val_accuracy: 0.8790
# Epoch 72/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3336 - accuracy: 0.8723 - val_loss: 0.3166 - val_accuracy: 0.8772
# Epoch 73/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3679 - accuracy: 0.8601 - val_loss: 0.2823 - val_accuracy: 0.8819
# Epoch 74/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3246 - accuracy: 0.8791 - val_loss: 0.3084 - val_accuracy: 0.8796
# Epoch 75/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3496 - accuracy: 0.8665 - val_loss: 0.3107 - val_accuracy: 0.8707
# Epoch 76/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3294 - accuracy: 0.8748 - val_loss: 0.3692 - val_accuracy: 0.8437
# Epoch 77/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3574 - accuracy: 0.8696 - val_loss: 0.2941 - val_accuracy: 0.8884
# Epoch 78/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3380 - accuracy: 0.8737 - val_loss: 0.3228 - val_accuracy: 0.8731
# Epoch 79/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3336 - accuracy: 0.8753 - val_loss: 0.3145 - val_accuracy: 0.8872
# Epoch 80/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3136 - accuracy: 0.8806 - val_loss: 0.3221 - val_accuracy: 0.8760
# Epoch 81/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3298 - accuracy: 0.8757 - val_loss: 0.2841 - val_accuracy: 0.8878
# Epoch 82/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3318 - accuracy: 0.8782 - val_loss: 0.2978 - val_accuracy: 0.8843
# Epoch 83/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3168 - accuracy: 0.8797 - val_loss: 0.3269 - val_accuracy: 0.8813
# Epoch 84/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3175 - accuracy: 0.8803 - val_loss: 0.3035 - val_accuracy: 0.8854
# Epoch 85/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.3312 - accuracy: 0.8731 - val_loss: 0.3007 - val_accuracy: 0.8825
# Epoch 86/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3596 - accuracy: 0.8679 - val_loss: 0.3178 - val_accuracy: 0.8813
# Epoch 87/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3370 - accuracy: 0.8755 - val_loss: 0.2880 - val_accuracy: 0.8860
# Epoch 88/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3175 - accuracy: 0.8840 - val_loss: 0.3568 - val_accuracy: 0.8655
# Epoch 89/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3143 - accuracy: 0.8798 - val_loss: 0.2748 - val_accuracy: 0.8948
# Epoch 90/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2947 - accuracy: 0.8859 - val_loss: 0.2623 - val_accuracy: 0.8925
# Epoch 91/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3027 - accuracy: 0.8836 - val_loss: 0.2862 - val_accuracy: 0.8813
# Epoch 92/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3121 - accuracy: 0.8825 - val_loss: 0.3448 - val_accuracy: 0.8719
# Epoch 93/400
# 60/60 [==============================] - 1s 23ms/step - loss: 0.3124 - accuracy: 0.8821 - val_loss: 0.2946 - val_accuracy: 0.8884
# Epoch 94/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3090 - accuracy: 0.8817 - val_loss: 0.3256 - val_accuracy: 0.8778
# Epoch 95/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3261 - accuracy: 0.8808 - val_loss: 0.2773 - val_accuracy: 0.8919
# Epoch 96/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.3070 - accuracy: 0.8871 - val_loss: 0.2773 - val_accuracy: 0.8942
# Epoch 97/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2893 - accuracy: 0.8911 - val_loss: 0.2949 - val_accuracy: 0.8860
# Epoch 98/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.3126 - accuracy: 0.8827 - val_loss: 0.3092 - val_accuracy: 0.8754
# Epoch 99/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2990 - accuracy: 0.8879 - val_loss: 0.2728 - val_accuracy: 0.8931
# Epoch 100/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3176 - accuracy: 0.8823 - val_loss: 0.2760 - val_accuracy: 0.8937
# Epoch 101/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3130 - accuracy: 0.8791 - val_loss: 0.3032 - val_accuracy: 0.8778
# Epoch 102/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3093 - accuracy: 0.8841 - val_loss: 0.2788 - val_accuracy: 0.8907
# Epoch 103/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2817 - accuracy: 0.8946 - val_loss: 0.2627 - val_accuracy: 0.8995
# Epoch 104/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2864 - accuracy: 0.8951 - val_loss: 0.2814 - val_accuracy: 0.8942
# Epoch 105/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3060 - accuracy: 0.8840 - val_loss: 0.2812 - val_accuracy: 0.8796
# Epoch 106/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2845 - accuracy: 0.8934 - val_loss: 0.2760 - val_accuracy: 0.8913
# Epoch 107/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2822 - accuracy: 0.8926 - val_loss: 0.3560 - val_accuracy: 0.8737
# Epoch 108/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.3065 - accuracy: 0.8858 - val_loss: 0.2774 - val_accuracy: 0.8925
# Epoch 109/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.3034 - accuracy: 0.8881 - val_loss: 0.2575 - val_accuracy: 0.8972
# Epoch 110/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2704 - accuracy: 0.8991 - val_loss: 0.2793 - val_accuracy: 0.8907
# Epoch 111/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2945 - accuracy: 0.8929 - val_loss: 0.2545 - val_accuracy: 0.8989
# Epoch 112/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2687 - accuracy: 0.8985 - val_loss: 0.2954 - val_accuracy: 0.8848
# Epoch 113/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2770 - accuracy: 0.8949 - val_loss: 0.2641 - val_accuracy: 0.8966
# Epoch 114/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2749 - accuracy: 0.8985 - val_loss: 0.3163 - val_accuracy: 0.8749
# Epoch 115/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2780 - accuracy: 0.8977 - val_loss: 0.2784 - val_accuracy: 0.8931
# Epoch 116/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2855 - accuracy: 0.8953 - val_loss: 0.2917 - val_accuracy: 0.8848
# Epoch 117/400
# 60/60 [==============================] - 1s 24ms/step - loss: 0.2835 - accuracy: 0.8938 - val_loss: 0.3159 - val_accuracy: 0.8778
# Epoch 118/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2966 - accuracy: 0.8892 - val_loss: 0.2596 - val_accuracy: 0.8984
# Epoch 119/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2780 - accuracy: 0.8971 - val_loss: 0.2724 - val_accuracy: 0.8960
# Epoch 120/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2570 - accuracy: 0.9037 - val_loss: 0.3161 - val_accuracy: 0.8796
# Epoch 121/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2732 - accuracy: 0.8958 - val_loss: 0.2810 - val_accuracy: 0.8901
# Epoch 122/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2687 - accuracy: 0.8996 - val_loss: 0.2891 - val_accuracy: 0.8913
# Epoch 123/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3014 - accuracy: 0.8895 - val_loss: 0.2642 - val_accuracy: 0.9048
# Epoch 124/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2713 - accuracy: 0.8981 - val_loss: 0.2798 - val_accuracy: 0.8942
# Epoch 125/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2717 - accuracy: 0.8992 - val_loss: 0.2396 - val_accuracy: 0.9113
# Epoch 126/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2585 - accuracy: 0.9054 - val_loss: 0.2480 - val_accuracy: 0.9060
# Epoch 127/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2824 - accuracy: 0.8947 - val_loss: 0.2898 - val_accuracy: 0.8860
# Epoch 128/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2732 - accuracy: 0.8998 - val_loss: 0.2806 - val_accuracy: 0.8989
# Epoch 129/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2736 - accuracy: 0.8988 - val_loss: 0.2636 - val_accuracy: 0.8984
# Epoch 130/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2577 - accuracy: 0.9050 - val_loss: 0.2460 - val_accuracy: 0.9060
# Epoch 131/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2398 - accuracy: 0.9110 - val_loss: 0.2542 - val_accuracy: 0.9019
# Epoch 132/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2611 - accuracy: 0.9026 - val_loss: 0.3089 - val_accuracy: 0.8901
# Epoch 133/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2730 - accuracy: 0.8996 - val_loss: 0.2530 - val_accuracy: 0.9007
# Epoch 134/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2462 - accuracy: 0.9072 - val_loss: 0.2476 - val_accuracy: 0.9072
# Epoch 135/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2507 - accuracy: 0.9047 - val_loss: 0.2805 - val_accuracy: 0.8995
# Epoch 136/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2689 - accuracy: 0.9012 - val_loss: 0.2710 - val_accuracy: 0.9007
# Epoch 137/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2371 - accuracy: 0.9087 - val_loss: 0.2869 - val_accuracy: 0.8972
# Epoch 138/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2628 - accuracy: 0.9039 - val_loss: 0.3123 - val_accuracy: 0.8937
# Epoch 139/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2955 - accuracy: 0.8911 - val_loss: 0.3253 - val_accuracy: 0.8807
# Epoch 140/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2831 - accuracy: 0.8941 - val_loss: 0.2761 - val_accuracy: 0.8989
# Epoch 141/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2671 - accuracy: 0.9032 - val_loss: 0.2750 - val_accuracy: 0.8989
# Epoch 142/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2486 - accuracy: 0.9065 - val_loss: 0.2881 - val_accuracy: 0.8878
# Epoch 143/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2413 - accuracy: 0.9081 - val_loss: 0.2468 - val_accuracy: 0.9113
# Epoch 144/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2682 - accuracy: 0.9000 - val_loss: 0.2509 - val_accuracy: 0.9083
# Epoch 145/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2449 - accuracy: 0.9082 - val_loss: 0.2760 - val_accuracy: 0.9001
# Epoch 146/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2596 - accuracy: 0.9014 - val_loss: 0.2987 - val_accuracy: 0.8890
# Epoch 147/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2639 - accuracy: 0.9023 - val_loss: 0.2834 - val_accuracy: 0.8937
# Epoch 148/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.3003 - accuracy: 0.8911 - val_loss: 0.2977 - val_accuracy: 0.8895
# Epoch 149/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2673 - accuracy: 0.9020 - val_loss: 0.3015 - val_accuracy: 0.8807
# Epoch 150/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2598 - accuracy: 0.9033 - val_loss: 0.2542 - val_accuracy: 0.9031
# Epoch 151/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2316 - accuracy: 0.9111 - val_loss: 0.2486 - val_accuracy: 0.9125
# Epoch 152/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2475 - accuracy: 0.9097 - val_loss: 0.2730 - val_accuracy: 0.8954
# Epoch 153/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2486 - accuracy: 0.9122 - val_loss: 0.3383 - val_accuracy: 0.8813
# Epoch 154/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2732 - accuracy: 0.8986 - val_loss: 0.2933 - val_accuracy: 0.9089
# Epoch 155/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2620 - accuracy: 0.9022 - val_loss: 0.2952 - val_accuracy: 0.8866
# Epoch 156/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2598 - accuracy: 0.9043 - val_loss: 0.2395 - val_accuracy: 0.9072
# Epoch 157/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2272 - accuracy: 0.9165 - val_loss: 0.2688 - val_accuracy: 0.8995
# Epoch 158/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2258 - accuracy: 0.9154 - val_loss: 0.3940 - val_accuracy: 0.8660
# Epoch 159/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2550 - accuracy: 0.9090 - val_loss: 0.2510 - val_accuracy: 0.9013
# Epoch 160/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2198 - accuracy: 0.9182 - val_loss: 0.2804 - val_accuracy: 0.8995
# Epoch 161/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2347 - accuracy: 0.9092 - val_loss: 0.2411 - val_accuracy: 0.9083
# Epoch 162/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2445 - accuracy: 0.9117 - val_loss: 0.2750 - val_accuracy: 0.9013
# Epoch 163/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2506 - accuracy: 0.9061 - val_loss: 0.2591 - val_accuracy: 0.9054
# Epoch 164/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2499 - accuracy: 0.9054 - val_loss: 0.2834 - val_accuracy: 0.8942
# Epoch 165/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2550 - accuracy: 0.9047 - val_loss: 0.3299 - val_accuracy: 0.8731
# Epoch 166/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2640 - accuracy: 0.9019 - val_loss: 0.2651 - val_accuracy: 0.8978
# Epoch 167/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2340 - accuracy: 0.9148 - val_loss: 0.2814 - val_accuracy: 0.9001
# Epoch 168/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2248 - accuracy: 0.9173 - val_loss: 0.2581 - val_accuracy: 0.9007
# Epoch 169/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2226 - accuracy: 0.9167 - val_loss: 0.2403 - val_accuracy: 0.9107
# Epoch 170/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2437 - accuracy: 0.9110 - val_loss: 0.2828 - val_accuracy: 0.8989
# Epoch 171/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2476 - accuracy: 0.9086 - val_loss: 0.2586 - val_accuracy: 0.9013
# Epoch 172/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2428 - accuracy: 0.9105 - val_loss: 0.2589 - val_accuracy: 0.9042
# Epoch 173/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2462 - accuracy: 0.9100 - val_loss: 0.2864 - val_accuracy: 0.8913
# Epoch 174/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2329 - accuracy: 0.9163 - val_loss: 0.2824 - val_accuracy: 0.9031
# Epoch 175/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2442 - accuracy: 0.9107 - val_loss: 0.2720 - val_accuracy: 0.8995
# Epoch 176/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2383 - accuracy: 0.9119 - val_loss: 0.2633 - val_accuracy: 0.9066
# Epoch 177/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2649 - accuracy: 0.9035 - val_loss: 0.2817 - val_accuracy: 0.8954
# Epoch 178/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2435 - accuracy: 0.9124 - val_loss: 0.3162 - val_accuracy: 0.8925
# Epoch 179/400
# 60/60 [==============================] - 1s 22ms/step - loss: 0.2256 - accuracy: 0.9164 - val_loss: 0.2599 - val_accuracy: 0.9101
# Epoch 180/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2287 - accuracy: 0.9148 - val_loss: 0.2769 - val_accuracy: 0.9042
# Epoch 181/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2271 - accuracy: 0.9186 - val_loss: 0.2358 - val_accuracy: 0.9142
# Epoch 182/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2313 - accuracy: 0.9187 - val_loss: 0.3067 - val_accuracy: 0.8901
# Epoch 183/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2284 - accuracy: 0.9167 - val_loss: 0.2467 - val_accuracy: 0.9125
# Epoch 184/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2059 - accuracy: 0.9246 - val_loss: 0.3040 - val_accuracy: 0.8989
# Epoch 185/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2487 - accuracy: 0.9117 - val_loss: 0.2905 - val_accuracy: 0.9019
# Epoch 186/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2418 - accuracy: 0.9152 - val_loss: 0.2639 - val_accuracy: 0.9042
# Epoch 187/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2281 - accuracy: 0.9146 - val_loss: 0.2575 - val_accuracy: 0.9125
# Epoch 188/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2403 - accuracy: 0.9126 - val_loss: 0.3728 - val_accuracy: 0.8672
# Epoch 189/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.1991 - accuracy: 0.9266 - val_loss: 0.3109 - val_accuracy: 0.8931
# Epoch 190/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2320 - accuracy: 0.9154 - val_loss: 0.2717 - val_accuracy: 0.9089
# Epoch 191/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2021 - accuracy: 0.9250 - val_loss: 0.3075 - val_accuracy: 0.8966
# Epoch 192/400
# 60/60 [==============================] - 1s 24ms/step - loss: 0.2223 - accuracy: 0.9171 - val_loss: 0.2593 - val_accuracy: 0.9042
# Epoch 193/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2239 - accuracy: 0.9182 - val_loss: 0.2855 - val_accuracy: 0.8966
# Epoch 194/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2088 - accuracy: 0.9237 - val_loss: 0.2840 - val_accuracy: 0.8913
# Epoch 195/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2180 - accuracy: 0.9204 - val_loss: 0.2664 - val_accuracy: 0.9107
# Epoch 196/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2165 - accuracy: 0.9202 - val_loss: 0.2787 - val_accuracy: 0.9001
# Epoch 197/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2634 - accuracy: 0.9075 - val_loss: 0.2629 - val_accuracy: 0.9036
# Epoch 198/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2130 - accuracy: 0.9212 - val_loss: 0.2597 - val_accuracy: 0.9142
# Epoch 199/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2168 - accuracy: 0.9214 - val_loss: 0.2851 - val_accuracy: 0.9048
# Epoch 200/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2031 - accuracy: 0.9263 - val_loss: 0.2702 - val_accuracy: 0.8960
# Epoch 201/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2126 - accuracy: 0.9204 - val_loss: 0.2945 - val_accuracy: 0.9007
# Epoch 202/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2022 - accuracy: 0.9254 - val_loss: 0.2438 - val_accuracy: 0.9183
# Epoch 203/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2146 - accuracy: 0.9206 - val_loss: 0.2911 - val_accuracy: 0.8960
# Epoch 204/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1998 - accuracy: 0.9280 - val_loss: 0.3149 - val_accuracy: 0.9019
# Epoch 205/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2236 - accuracy: 0.9226 - val_loss: 0.2362 - val_accuracy: 0.9154
# Epoch 206/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.1944 - accuracy: 0.9259 - val_loss: 0.2558 - val_accuracy: 0.9142
# Epoch 207/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2246 - accuracy: 0.9188 - val_loss: 0.2753 - val_accuracy: 0.8995
# Epoch 208/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2116 - accuracy: 0.9229 - val_loss: 0.3574 - val_accuracy: 0.8766
# Epoch 209/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2333 - accuracy: 0.9152 - val_loss: 0.2739 - val_accuracy: 0.9066
# Epoch 210/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2034 - accuracy: 0.9248 - val_loss: 0.2632 - val_accuracy: 0.9142
# Epoch 211/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2066 - accuracy: 0.9248 - val_loss: 0.2406 - val_accuracy: 0.9201
# Epoch 212/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2184 - accuracy: 0.9209 - val_loss: 0.2726 - val_accuracy: 0.9119
# Epoch 213/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1982 - accuracy: 0.9264 - val_loss: 0.2966 - val_accuracy: 0.9048
# Epoch 214/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2409 - accuracy: 0.9139 - val_loss: 0.2738 - val_accuracy: 0.9007
# Epoch 215/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2132 - accuracy: 0.9231 - val_loss: 0.2885 - val_accuracy: 0.9078
# Epoch 216/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1964 - accuracy: 0.9276 - val_loss: 0.2735 - val_accuracy: 0.9054
# Epoch 217/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2203 - accuracy: 0.9224 - val_loss: 0.2621 - val_accuracy: 0.9154
# Epoch 218/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2070 - accuracy: 0.9217 - val_loss: 0.2815 - val_accuracy: 0.9025
# Epoch 219/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2123 - accuracy: 0.9233 - val_loss: 0.3130 - val_accuracy: 0.8942
# Epoch 220/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2119 - accuracy: 0.9218 - val_loss: 0.3958 - val_accuracy: 0.8766
# Epoch 221/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2343 - accuracy: 0.9131 - val_loss: 0.2460 - val_accuracy: 0.9136
# Epoch 222/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2049 - accuracy: 0.9235 - val_loss: 0.2944 - val_accuracy: 0.9019
# Epoch 223/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2119 - accuracy: 0.9256 - val_loss: 0.2583 - val_accuracy: 0.9048
# Epoch 224/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2286 - accuracy: 0.9187 - val_loss: 0.2399 - val_accuracy: 0.9101
# Epoch 225/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2056 - accuracy: 0.9262 - val_loss: 0.2458 - val_accuracy: 0.9183
# Epoch 226/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1875 - accuracy: 0.9322 - val_loss: 0.2557 - val_accuracy: 0.9172
# Epoch 227/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2097 - accuracy: 0.9250 - val_loss: 0.2518 - val_accuracy: 0.9119
# Epoch 228/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1992 - accuracy: 0.9279 - val_loss: 0.2904 - val_accuracy: 0.8984
# Epoch 229/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2340 - accuracy: 0.9129 - val_loss: 0.3000 - val_accuracy: 0.8989
# Epoch 230/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.2069 - accuracy: 0.9260 - val_loss: 0.2462 - val_accuracy: 0.9136
# Epoch 231/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2077 - accuracy: 0.9270 - val_loss: 0.2427 - val_accuracy: 0.9224
# Epoch 232/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1928 - accuracy: 0.9279 - val_loss: 0.3605 - val_accuracy: 0.8872
# Epoch 233/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2065 - accuracy: 0.9261 - val_loss: 0.2646 - val_accuracy: 0.9083
# Epoch 234/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1917 - accuracy: 0.9318 - val_loss: 0.2534 - val_accuracy: 0.9119
# Epoch 235/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1904 - accuracy: 0.9310 - val_loss: 0.3230 - val_accuracy: 0.8989
# Epoch 236/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2178 - accuracy: 0.9237 - val_loss: 0.3490 - val_accuracy: 0.8837
# Epoch 237/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1981 - accuracy: 0.9289 - val_loss: 0.2484 - val_accuracy: 0.9172
# Epoch 238/400
# 60/60 [==============================] - 1s 17ms/step - loss: 0.1994 - accuracy: 0.9263 - val_loss: 0.2831 - val_accuracy: 0.9148
# Epoch 239/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1967 - accuracy: 0.9303 - val_loss: 0.2779 - val_accuracy: 0.8989
# Epoch 240/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2019 - accuracy: 0.9271 - val_loss: 0.2796 - val_accuracy: 0.9083
# Epoch 241/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2049 - accuracy: 0.9269 - val_loss: 0.2549 - val_accuracy: 0.9148
# Epoch 242/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1905 - accuracy: 0.9310 - val_loss: 0.2679 - val_accuracy: 0.9066
# Epoch 243/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1847 - accuracy: 0.9333 - val_loss: 0.2750 - val_accuracy: 0.9113
# Epoch 244/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2547 - accuracy: 0.9093 - val_loss: 0.3047 - val_accuracy: 0.8966
# Epoch 245/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1911 - accuracy: 0.9314 - val_loss: 0.2768 - val_accuracy: 0.9183
# Epoch 246/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2134 - accuracy: 0.9238 - val_loss: 0.2654 - val_accuracy: 0.9125
# Epoch 247/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2065 - accuracy: 0.9286 - val_loss: 0.2681 - val_accuracy: 0.9119
# Epoch 248/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2039 - accuracy: 0.9285 - val_loss: 0.2342 - val_accuracy: 0.9189
# Epoch 249/400
# 60/60 [==============================] - 1s 22ms/step - loss: 0.1828 - accuracy: 0.9356 - val_loss: 0.2946 - val_accuracy: 0.8984
# Epoch 250/400
# 60/60 [==============================] - 1s 22ms/step - loss: 0.2159 - accuracy: 0.9207 - val_loss: 0.2325 - val_accuracy: 0.9219
# Epoch 251/400
# 60/60 [==============================] - 1s 22ms/step - loss: 0.1847 - accuracy: 0.9354 - val_loss: 0.2974 - val_accuracy: 0.9013
# Epoch 252/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1836 - accuracy: 0.9321 - val_loss: 0.3384 - val_accuracy: 0.8960
# Epoch 253/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2226 - accuracy: 0.9208 - val_loss: 0.2547 - val_accuracy: 0.9177
# Epoch 254/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2080 - accuracy: 0.9275 - val_loss: 0.2635 - val_accuracy: 0.9172
# Epoch 255/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1878 - accuracy: 0.9345 - val_loss: 0.2535 - val_accuracy: 0.9148
# Epoch 256/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1837 - accuracy: 0.9330 - val_loss: 0.2972 - val_accuracy: 0.9095
# Epoch 257/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1981 - accuracy: 0.9293 - val_loss: 0.2677 - val_accuracy: 0.9160
# Epoch 258/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2201 - accuracy: 0.9204 - val_loss: 0.2535 - val_accuracy: 0.9125
# Epoch 259/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1855 - accuracy: 0.9323 - val_loss: 0.2988 - val_accuracy: 0.9130
# Epoch 260/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2051 - accuracy: 0.9258 - val_loss: 0.2518 - val_accuracy: 0.9177
# Epoch 261/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1667 - accuracy: 0.9392 - val_loss: 0.2356 - val_accuracy: 0.9236
# Epoch 262/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1811 - accuracy: 0.9350 - val_loss: 0.2853 - val_accuracy: 0.9060
# Epoch 263/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1972 - accuracy: 0.9289 - val_loss: 0.3349 - val_accuracy: 0.9054
# Epoch 264/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2075 - accuracy: 0.9289 - val_loss: 0.2706 - val_accuracy: 0.9107
# Epoch 265/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1955 - accuracy: 0.9282 - val_loss: 0.2346 - val_accuracy: 0.9224
# Epoch 266/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2353 - accuracy: 0.9180 - val_loss: 0.2639 - val_accuracy: 0.9060
# Epoch 267/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1933 - accuracy: 0.9313 - val_loss: 0.2755 - val_accuracy: 0.9007
# Epoch 268/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1975 - accuracy: 0.9265 - val_loss: 0.2983 - val_accuracy: 0.9089
# Epoch 269/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1940 - accuracy: 0.9299 - val_loss: 0.2452 - val_accuracy: 0.9260
# Epoch 270/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2076 - accuracy: 0.9256 - val_loss: 0.2692 - val_accuracy: 0.9078
# Epoch 271/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1892 - accuracy: 0.9320 - val_loss: 0.2697 - val_accuracy: 0.9031
# Epoch 272/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1981 - accuracy: 0.9250 - val_loss: 0.2771 - val_accuracy: 0.9089
# Epoch 273/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1992 - accuracy: 0.9297 - val_loss: 0.2865 - val_accuracy: 0.9007
# Epoch 274/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1797 - accuracy: 0.9352 - val_loss: 0.2624 - val_accuracy: 0.9236
# Epoch 275/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1776 - accuracy: 0.9368 - val_loss: 0.2432 - val_accuracy: 0.9224
# Epoch 276/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1805 - accuracy: 0.9363 - val_loss: 0.2758 - val_accuracy: 0.9083
# Epoch 277/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1902 - accuracy: 0.9337 - val_loss: 0.2802 - val_accuracy: 0.9119
# Epoch 278/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1812 - accuracy: 0.9338 - val_loss: 0.2740 - val_accuracy: 0.9130
# Epoch 279/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1806 - accuracy: 0.9346 - val_loss: 0.2649 - val_accuracy: 0.9113
# Epoch 280/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2028 - accuracy: 0.9292 - val_loss: 0.3440 - val_accuracy: 0.8784
# Epoch 281/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2068 - accuracy: 0.9253 - val_loss: 0.2273 - val_accuracy: 0.9230
# Epoch 282/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2081 - accuracy: 0.9278 - val_loss: 0.2908 - val_accuracy: 0.9095
# Epoch 283/400
# 60/60 [==============================] - 1s 22ms/step - loss: 0.1981 - accuracy: 0.9285 - val_loss: 0.3361 - val_accuracy: 0.8895
# Epoch 284/400
# 60/60 [==============================] - 2s 27ms/step - loss: 0.1840 - accuracy: 0.9348 - val_loss: 0.2713 - val_accuracy: 0.9042
# Epoch 285/400
# 60/60 [==============================] - 2s 27ms/step - loss: 0.1936 - accuracy: 0.9309 - val_loss: 0.2824 - val_accuracy: 0.9130
# Epoch 286/400
# 60/60 [==============================] - 2s 29ms/step - loss: 0.1917 - accuracy: 0.9333 - val_loss: 0.2675 - val_accuracy: 0.9130
# Epoch 287/400
# 60/60 [==============================] - 2s 32ms/step - loss: 0.1839 - accuracy: 0.9329 - val_loss: 0.3356 - val_accuracy: 0.8978
# Epoch 288/400
# 60/60 [==============================] - 2s 31ms/step - loss: 0.1868 - accuracy: 0.9356 - val_loss: 0.2610 - val_accuracy: 0.9207
# Epoch 289/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1754 - accuracy: 0.9379 - val_loss: 0.2741 - val_accuracy: 0.9078
# Epoch 290/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1948 - accuracy: 0.9316 - val_loss: 0.2860 - val_accuracy: 0.9072
# Epoch 291/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1789 - accuracy: 0.9341 - val_loss: 0.2660 - val_accuracy: 0.9136
# Epoch 292/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1854 - accuracy: 0.9346 - val_loss: 0.2572 - val_accuracy: 0.9201
# Epoch 293/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1751 - accuracy: 0.9373 - val_loss: 0.2692 - val_accuracy: 0.9154
# Epoch 294/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2029 - accuracy: 0.9302 - val_loss: 0.2576 - val_accuracy: 0.9177
# Epoch 295/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1730 - accuracy: 0.9381 - val_loss: 0.2829 - val_accuracy: 0.9130
# Epoch 296/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1899 - accuracy: 0.9324 - val_loss: 0.2743 - val_accuracy: 0.9119
# Epoch 297/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1836 - accuracy: 0.9365 - val_loss: 0.2975 - val_accuracy: 0.9130
# Epoch 298/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1822 - accuracy: 0.9351 - val_loss: 0.2487 - val_accuracy: 0.9213
# Epoch 299/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1852 - accuracy: 0.9342 - val_loss: 0.2694 - val_accuracy: 0.9125
# Epoch 300/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1915 - accuracy: 0.9322 - val_loss: 0.2604 - val_accuracy: 0.9260
# Epoch 301/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1715 - accuracy: 0.9387 - val_loss: 0.3635 - val_accuracy: 0.8931
# Epoch 302/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2339 - accuracy: 0.9189 - val_loss: 0.2705 - val_accuracy: 0.9148
# Epoch 303/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1859 - accuracy: 0.9358 - val_loss: 0.2448 - val_accuracy: 0.9271
# Epoch 304/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1623 - accuracy: 0.9400 - val_loss: 0.2515 - val_accuracy: 0.9230
# Epoch 305/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1710 - accuracy: 0.9394 - val_loss: 0.2795 - val_accuracy: 0.9113
# Epoch 306/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2006 - accuracy: 0.9272 - val_loss: 0.2857 - val_accuracy: 0.9201
# Epoch 307/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1853 - accuracy: 0.9367 - val_loss: 0.2631 - val_accuracy: 0.9136
# Epoch 308/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1990 - accuracy: 0.9304 - val_loss: 0.3273 - val_accuracy: 0.8972
# Epoch 309/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1641 - accuracy: 0.9422 - val_loss: 0.3310 - val_accuracy: 0.9036
# Epoch 310/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1736 - accuracy: 0.9396 - val_loss: 0.2646 - val_accuracy: 0.9224
# Epoch 311/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1950 - accuracy: 0.9313 - val_loss: 0.2586 - val_accuracy: 0.9242
# Epoch 312/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1751 - accuracy: 0.9401 - val_loss: 0.2493 - val_accuracy: 0.9136
# Epoch 313/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1871 - accuracy: 0.9332 - val_loss: 0.3242 - val_accuracy: 0.8995
# Epoch 314/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1826 - accuracy: 0.9346 - val_loss: 0.2543 - val_accuracy: 0.9148
# Epoch 315/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2023 - accuracy: 0.9271 - val_loss: 0.3631 - val_accuracy: 0.8925
# Epoch 316/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1897 - accuracy: 0.9333 - val_loss: 0.2577 - val_accuracy: 0.9166
# Epoch 317/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2012 - accuracy: 0.9303 - val_loss: 0.2743 - val_accuracy: 0.9183
# Epoch 318/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1866 - accuracy: 0.9348 - val_loss: 0.2971 - val_accuracy: 0.9072
# Epoch 319/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1900 - accuracy: 0.9337 - val_loss: 0.2657 - val_accuracy: 0.9113
# Epoch 320/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2119 - accuracy: 0.9265 - val_loss: 0.3261 - val_accuracy: 0.9078
# Epoch 321/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1781 - accuracy: 0.9366 - val_loss: 0.2615 - val_accuracy: 0.9224
# Epoch 322/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1671 - accuracy: 0.9397 - val_loss: 0.2879 - val_accuracy: 0.9083
# Epoch 323/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1729 - accuracy: 0.9383 - val_loss: 0.3152 - val_accuracy: 0.9007
# Epoch 324/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1682 - accuracy: 0.9389 - val_loss: 0.2627 - val_accuracy: 0.9201
# Epoch 325/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1615 - accuracy: 0.9429 - val_loss: 0.2818 - val_accuracy: 0.9125
# Epoch 326/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1775 - accuracy: 0.9353 - val_loss: 0.2848 - val_accuracy: 0.9201
# Epoch 327/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2063 - accuracy: 0.9273 - val_loss: 0.3455 - val_accuracy: 0.8884
# Epoch 328/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.2194 - accuracy: 0.9227 - val_loss: 0.3766 - val_accuracy: 0.8831
# Epoch 329/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1901 - accuracy: 0.9321 - val_loss: 0.2655 - val_accuracy: 0.9213
# Epoch 330/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1843 - accuracy: 0.9363 - val_loss: 0.3252 - val_accuracy: 0.9078
# Epoch 331/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1860 - accuracy: 0.9338 - val_loss: 0.2587 - val_accuracy: 0.9166
# Epoch 332/400
# 60/60 [==============================] - 1s 18ms/step - loss: 0.1673 - accuracy: 0.9412 - val_loss: 0.2444 - val_accuracy: 0.9242
# Epoch 333/400
# ...
# Epoch 299/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1934 - accuracy: 0.9286 - val_loss: 0.2729 - val_accuracy: 0.9148
# Epoch 300/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2234 - accuracy: 0.9222 - val_loss: 0.2897 - val_accuracy: 0.9060
# Epoch 301/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1982 - accuracy: 0.9293 - val_loss: 0.2883 - val_accuracy: 0.9113
# Epoch 302/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1954 - accuracy: 0.9316 - val_loss: 0.3393 - val_accuracy: 0.9025
# Epoch 303/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1983 - accuracy: 0.9303 - val_loss: 0.2917 - val_accuracy: 0.9136
# Epoch 304/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1920 - accuracy: 0.9312 - val_loss: 0.2465 - val_accuracy: 0.9142
# Epoch 305/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1882 - accuracy: 0.9329 - val_loss: 0.3575 - val_accuracy: 0.8948
# Epoch 306/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1825 - accuracy: 0.9349 - val_loss: 0.2917 - val_accuracy: 0.9166
# Epoch 307/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1838 - accuracy: 0.9325 - val_loss: 0.3371 - val_accuracy: 0.9160
# Epoch 308/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1788 - accuracy: 0.9362 - val_loss: 0.4145 - val_accuracy: 0.8819
# Epoch 309/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2097 - accuracy: 0.9280 - val_loss: 0.2874 - val_accuracy: 0.9095
# Epoch 310/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2157 - accuracy: 0.9245 - val_loss: 0.2995 - val_accuracy: 0.9107
# Epoch 311/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1977 - accuracy: 0.9282 - val_loss: 0.2406 - val_accuracy: 0.9154
# Epoch 312/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1859 - accuracy: 0.9367 - val_loss: 0.2672 - val_accuracy: 0.9166
# Epoch 313/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1929 - accuracy: 0.9312 - val_loss: 0.2944 - val_accuracy: 0.9031
# Epoch 314/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2112 - accuracy: 0.9237 - val_loss: 0.2831 - val_accuracy: 0.9042
# Epoch 315/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1928 - accuracy: 0.9306 - val_loss: 0.2777 - val_accuracy: 0.9113
# Epoch 316/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1998 - accuracy: 0.9288 - val_loss: 0.2947 - val_accuracy: 0.9072
# Epoch 317/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2223 - accuracy: 0.9209 - val_loss: 0.3701 - val_accuracy: 0.8854
# Epoch 318/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1966 - accuracy: 0.9297 - val_loss: 0.2849 - val_accuracy: 0.9219
# Epoch 319/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1963 - accuracy: 0.9291 - val_loss: 0.2669 - val_accuracy: 0.9201
# Epoch 320/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1886 - accuracy: 0.9352 - val_loss: 0.3162 - val_accuracy: 0.9031
# Epoch 321/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1894 - accuracy: 0.9341 - val_loss: 0.2886 - val_accuracy: 0.9136
# Epoch 322/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1859 - accuracy: 0.9342 - val_loss: 0.3030 - val_accuracy: 0.9066
# Epoch 323/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1763 - accuracy: 0.9365 - val_loss: 0.2319 - val_accuracy: 0.9207
# Epoch 324/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1894 - accuracy: 0.9330 - val_loss: 0.2504 - val_accuracy: 0.9207
# Epoch 325/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1858 - accuracy: 0.9344 - val_loss: 0.2523 - val_accuracy: 0.9183
# Epoch 326/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1865 - accuracy: 0.9329 - val_loss: 0.2720 - val_accuracy: 0.9195
# Epoch 327/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1685 - accuracy: 0.9399 - val_loss: 0.2805 - val_accuracy: 0.9083
# Epoch 328/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1893 - accuracy: 0.9338 - val_loss: 0.2953 - val_accuracy: 0.9019
# Epoch 329/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1982 - accuracy: 0.9319 - val_loss: 0.3459 - val_accuracy: 0.9036
# Epoch 330/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1822 - accuracy: 0.9340 - val_loss: 0.3092 - val_accuracy: 0.8989
# Epoch 331/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1832 - accuracy: 0.9359 - val_loss: 0.2457 - val_accuracy: 0.9189
# Epoch 332/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1894 - accuracy: 0.9313 - val_loss: 0.2794 - val_accuracy: 0.9142
# Epoch 333/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2028 - accuracy: 0.9296 - val_loss: 0.2754 - val_accuracy: 0.9113
# Epoch 334/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2151 - accuracy: 0.9212 - val_loss: 0.3177 - val_accuracy: 0.9019
# Epoch 335/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2179 - accuracy: 0.9232 - val_loss: 0.3266 - val_accuracy: 0.9036
# Epoch 336/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1987 - accuracy: 0.9305 - val_loss: 0.3001 - val_accuracy: 0.9107
# Epoch 337/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1888 - accuracy: 0.9328 - val_loss: 0.3533 - val_accuracy: 0.8907
# Epoch 338/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1919 - accuracy: 0.9318 - val_loss: 0.2725 - val_accuracy: 0.9125
# Epoch 339/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.2050 - accuracy: 0.9309 - val_loss: 0.3258 - val_accuracy: 0.8843
# Epoch 340/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2254 - accuracy: 0.9224 - val_loss: 0.2768 - val_accuracy: 0.9136
# Epoch 341/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1763 - accuracy: 0.9354 - val_loss: 0.2902 - val_accuracy: 0.9177
# Epoch 342/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1868 - accuracy: 0.9327 - val_loss: 0.2769 - val_accuracy: 0.9078
# Epoch 343/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2149 - accuracy: 0.9263 - val_loss: 0.2595 - val_accuracy: 0.9148
# Epoch 344/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1837 - accuracy: 0.9373 - val_loss: 0.2754 - val_accuracy: 0.9125
# Epoch 345/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1656 - accuracy: 0.9412 - val_loss: 0.2925 - val_accuracy: 0.9142
# Epoch 346/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1836 - accuracy: 0.9347 - val_loss: 0.2702 - val_accuracy: 0.9089
# Epoch 347/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1934 - accuracy: 0.9313 - val_loss: 0.2974 - val_accuracy: 0.9089
# Epoch 348/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2123 - accuracy: 0.9244 - val_loss: 0.2859 - val_accuracy: 0.9172
# Epoch 349/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1730 - accuracy: 0.9383 - val_loss: 0.2863 - val_accuracy: 0.9119
# Epoch 350/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1829 - accuracy: 0.9353 - val_loss: 0.2695 - val_accuracy: 0.9136
# Epoch 351/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1825 - accuracy: 0.9371 - val_loss: 0.2843 - val_accuracy: 0.9130
# Epoch 352/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1867 - accuracy: 0.9344 - val_loss: 0.3185 - val_accuracy: 0.9130
# Epoch 353/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1943 - accuracy: 0.9336 - val_loss: 0.2809 - val_accuracy: 0.9095
# Epoch 354/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1678 - accuracy: 0.9408 - val_loss: 0.2439 - val_accuracy: 0.9236
# Epoch 355/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1778 - accuracy: 0.9378 - val_loss: 0.3402 - val_accuracy: 0.9031
# Epoch 356/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1763 - accuracy: 0.9386 - val_loss: 0.2638 - val_accuracy: 0.9248
# Epoch 357/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1675 - accuracy: 0.9402 - val_loss: 0.2781 - val_accuracy: 0.9148
# Epoch 358/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1669 - accuracy: 0.9414 - val_loss: 0.2623 - val_accuracy: 0.9154
# Epoch 359/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1722 - accuracy: 0.9410 - val_loss: 0.3876 - val_accuracy: 0.8995
# Epoch 360/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2112 - accuracy: 0.9257 - val_loss: 0.3404 - val_accuracy: 0.8890
# Epoch 361/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.2097 - accuracy: 0.9288 - val_loss: 0.2523 - val_accuracy: 0.9166
# Epoch 362/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1886 - accuracy: 0.9338 - val_loss: 0.3929 - val_accuracy: 0.8702
# Epoch 363/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2214 - accuracy: 0.9253 - val_loss: 0.2946 - val_accuracy: 0.9236
# Epoch 364/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1823 - accuracy: 0.9363 - val_loss: 0.2661 - val_accuracy: 0.9148
# Epoch 365/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1657 - accuracy: 0.9423 - val_loss: 0.3331 - val_accuracy: 0.8960
# Epoch 366/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1634 - accuracy: 0.9399 - val_loss: 0.2750 - val_accuracy: 0.9148
# Epoch 367/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1883 - accuracy: 0.9320 - val_loss: 0.2511 - val_accuracy: 0.9148
# Epoch 368/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2143 - accuracy: 0.9252 - val_loss: 0.2959 - val_accuracy: 0.9019
# Epoch 369/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1952 - accuracy: 0.9321 - val_loss: 0.2749 - val_accuracy: 0.9207
# Epoch 370/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1791 - accuracy: 0.9389 - val_loss: 0.2589 - val_accuracy: 0.9154
# Epoch 371/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1798 - accuracy: 0.9359 - val_loss: 0.2558 - val_accuracy: 0.9213
# Epoch 372/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.2012 - accuracy: 0.9303 - val_loss: 0.2554 - val_accuracy: 0.9195
# Epoch 373/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1825 - accuracy: 0.9389 - val_loss: 0.2750 - val_accuracy: 0.9142
# Epoch 374/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1780 - accuracy: 0.9373 - val_loss: 0.3305 - val_accuracy: 0.9083
# Epoch 375/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1753 - accuracy: 0.9372 - val_loss: 0.2879 - val_accuracy: 0.9154
# Epoch 376/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1835 - accuracy: 0.9333 - val_loss: 0.2674 - val_accuracy: 0.9236
# Epoch 377/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1759 - accuracy: 0.9381 - val_loss: 0.2706 - val_accuracy: 0.9242
# Epoch 378/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1707 - accuracy: 0.9427 - val_loss: 0.2763 - val_accuracy: 0.9219
# Epoch 379/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1722 - accuracy: 0.9412 - val_loss: 0.2853 - val_accuracy: 0.9025
# Epoch 380/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1840 - accuracy: 0.9344 - val_loss: 0.2798 - val_accuracy: 0.9101
# Epoch 381/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2041 - accuracy: 0.9310 - val_loss: 0.2834 - val_accuracy: 0.9166
# Epoch 382/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1876 - accuracy: 0.9358 - val_loss: 0.2951 - val_accuracy: 0.9172
# Epoch 383/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1952 - accuracy: 0.9326 - val_loss: 0.2683 - val_accuracy: 0.9183
# Epoch 384/400
# 60/60 [==============================] - 1s 21ms/step - loss: 0.1685 - accuracy: 0.9402 - val_loss: 0.2831 - val_accuracy: 0.9060
# Epoch 385/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1812 - accuracy: 0.9369 - val_loss: 0.3134 - val_accuracy: 0.9083
# Epoch 386/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1803 - accuracy: 0.9365 - val_loss: 0.2805 - val_accuracy: 0.9107
# Epoch 387/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1907 - accuracy: 0.9340 - val_loss: 0.3274 - val_accuracy: 0.9089
# Epoch 388/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1845 - accuracy: 0.9382 - val_loss: 0.2648 - val_accuracy: 0.9125
# Epoch 389/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1819 - accuracy: 0.9363 - val_loss: 0.2589 - val_accuracy: 0.9113
# Epoch 390/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1705 - accuracy: 0.9412 - val_loss: 0.2731 - val_accuracy: 0.9113
# Epoch 391/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1740 - accuracy: 0.9382 - val_loss: 0.2958 - val_accuracy: 0.9113
# Epoch 392/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1656 - accuracy: 0.9418 - val_loss: 0.2702 - val_accuracy: 0.9207
# Epoch 393/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1754 - accuracy: 0.9398 - val_loss: 0.2829 - val_accuracy: 0.9148
# Epoch 394/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1730 - accuracy: 0.9379 - val_loss: 0.2839 - val_accuracy: 0.9119
# Epoch 395/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.2051 - accuracy: 0.9300 - val_loss: 0.2671 - val_accuracy: 0.9166
# Epoch 396/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1693 - accuracy: 0.9438 - val_loss: 0.2826 - val_accuracy: 0.9107
# Epoch 397/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1816 - accuracy: 0.9385 - val_loss: 0.3075 - val_accuracy: 0.9007
# Epoch 398/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1940 - accuracy: 0.9322 - val_loss: 0.3183 - val_accuracy: 0.9089
# Epoch 399/400
# 60/60 [==============================] - 1s 20ms/step - loss: 0.1679 - accuracy: 0.9420 - val_loss: 0.2717 - val_accuracy: 0.9172
# Epoch 400/400
# 60/60 [==============================] - 1s 19ms/step - loss: 0.1889 - accuracy: 0.9346 - val_loss: 0.2855 - val_accuracy: 0.9160
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2527 - accuracy: 0.9244
# Test loss: 0.25274237990379333
# Test accuracy: 0.9243786334991455
# 8/8 [==============================] - 0s 10ms/step
# 1891it [00:00, 14424.14it/s]
# Confusion Matrix
# [[236   0   0   3  21   2   0]
#  [  2  89   0   2   1   5   0]
#  [  0   0  73   2   0   4  10]
#  [  8   4   3 609   8   2   1]
#  [ 10   0   0   6 403   2   5]
#  [  5   5   1   1   2 239  16]
#  [  0   0   4   1   6   1  99]]
#                 precision    recall  f1-score   support
#
#         Asthma       0.90      0.90      0.90       262
# Broncheostasis       0.91      0.90      0.90        99
#  Bronchiolitis       0.90      0.82      0.86        89
#           COPD       0.98      0.96      0.97       635
#        Healthy       0.91      0.95      0.93       426
#      Pneumonia       0.94      0.89      0.91       269
#           URTI       0.76      0.89      0.82       111
#
#       accuracy                           0.92      1891
#      macro avg       0.90      0.90      0.90      1891
#   weighted avg       0.93      0.92      0.92      1891
#
# ================================================================================================

# %%
#loading the autoencoder model
#X_train_1,X_test,Y_train_1,Y_test=train_test_split(X,Y,test_size=0.1,random_state=10)
from tensorflow.keras.models import Model
import tensorflow as tf
model.load_weights("/content/gdrive/MyDrive/all_disease_classification/train_on_16_06_22/fold_2_2022_06_16_11_31_22.h5")
#model.load_weights
out_dense= Model(inputs=model.input,outputs=model.get_layer('dense').output)
Y_denseout = out_dense.predict(X_test)
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2,learning_rate='auto',init='random')
Y_embedded = tsne.fit_transform(Y_denseout)
Y_predicted=pd.DataFrame(Y_test,columns=['Asthma','Broncheostasis','Bronchiolitis','COPD','Healthy','Pneumonia','URTI'])
Y_ori=[];Asthma_t=0;Broncheostasis_t=0;Bronchiolitis_t=0;COPD_t=0;Healthy_t=0;Pneumonia_t=0;URTI_t=0;
for index,row in tqdm(Y_predicted.iterrows()):
   if row['Asthma']==1:
     Asthma_t=Asthma_t+1
     Y_ori.append(0)
   elif row['Broncheostasis']==1:
      Broncheostasis_t=Broncheostasis_t+1
      Y_ori.append(1)
   elif row['Bronchiolitis']==1:
      Bronchiolitis_t=Bronchiolitis_t+1
      Y_ori.append(2)
   elif row['COPD']==1:
       COPD_t=COPD_t+1
       Y_ori.append(3)
   elif row['Healthy']==1:
       Healthy_t=Healthy_t+1
       Y_ori.append(4)
   elif row['Pneumonia']==1:
       Pneumonia_t=Pneumonia_t+1
       Y_ori.append(5)
   elif row['URTI']==1:
      URTI_t=URTI_t+1
      Y_ori.append(6)

q=np.array(Y_ori)
label_l=[]
for i in range (X_test.shape[0]):
  if q[i]==0:
    label_l.append('Asthma')
  elif q[i]==1:
    label_l.append('Broncheostasis')
  elif q[i]==2:
    label_l.append('Bronchiolitis')
  elif q[i]==3:
    label_l.append('COPD')
  elif q[i]==4:
    label_l.append('Healthy')
  elif q[i]==5:
    label_l.append('Pneumonia')
  elif q[i]==6:
    label_l.append('URTI')

Label_ar=np.array(label_l)
# Out:
# 1891it [00:00, 15270.31it/s]

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.scatterplot(Y_embedded[:,0], Y_embedded[:,1], hue=Label_ar)
plt.xlabel("Dimension 1",fontweight ='bold', fontsize = 15);plt.ylabel("Dimenssion 2",fontweight ='bold', fontsize = 15)
plt.title('t-SNE plot After applying Lightweight CNN',fontweight ='bold', fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 't-SNE plot After applying Lightweight CNN')
